# %%
import pickle
from sage.all import sigma, nth_prime, matrix, QQ, ComplexIntervalField, polygen, log, list_plot, flatten, pari



def tau(n):
    def step1(n, k):
        return 35*k^4 - 52*k^3*n + 18*k^2*n^2
    def step2(n, k):
        return sigma(k) * sigma(n - k)
    def step3(n):
        ans = 0
        for k in range(1, n):
            ans=ans+step1(n, k) * step2(n, k)
        return 24*ans
    return n^4 * sigma(n) - step3(n)

def tauprime_plus1(k):
            pn=nth_prime(k)
            return tau(pn+1)

tauprime_plus1_list=[tauprime_plus1(k) for k in range(1,401)]
j_list=[(0,1)] # first entry is just an offset. 
h_list=[1]+tauprime_plus1_list

for n in range(1,401):# so j(1) = 1 = h(0) as required.
    sm=0
    for r in [1..n-1]: 
        sm=sm+j_list[r][1]*h_list[n-r] 
    j_n=n*h_list[n]-sm
    print("j:",n)
    j_list.append((n,j_n))
    

with open('/Users/barrybrent/data2/run5april26no1.txt', 'wb') as wfile:
    pickle.dump(tauprime_plus1_list, wfile) 
    
with open('/Users/barrybrent/data2/run5april26no2.txt', 'wb') as wfile:
    pickle.dump(j_list, wfile) 



def P_matrix(lst):
    lenlist=len(lst)
    columns=[lst]
    for k in range(1,lenlist):
        column=[0]*(k-1)
        column=column+[-k]
        column=flatten(column+[lst])
        column=column+[lst]
        column=column[:lenlist]
        columns+=[column]
    return matrix(columns).transpose()




precision_bits = 100
CC = ComplexField(precision_bits)
x = polygen(QQ)


charpol_list = []
roots_list = []



mins_list = []





for n in range(2, 351):  # Changed to 401 to match j_list size
    
    print("n:",n)
    
    vals=[a
    pl = P_matrix(j_list[:n])
    det = pl.det()
   
   
    
    
    cp = pl.charpoly()
    charpol_list.append((n, cp))
    
    
    roots = cp.roots(ring=CC, multiplicities=False)
    roots_list.append((n, roots))
    
    
    
    aar = [r.abs() for r in roots]
    aar_list.append((n, aar))
    
    
    if aar:
        minn = min(aar)
        mins_list.append((n, minn))
        
        if minn > 0:
            log_minn = log(minn)
            log_mins_list.append((n, log_minn))

p = list_plot(mins_list, plotjoined=True, axes_labels=['', ''])
print("MINIMUM MODULI")
p.show()



with open('/Users/barrybrent/data2/run5april26no3.txt', 'wb') as wfile:
    pickle.dump(charpol_list, wfile) 
    
with open('/Users/barrybrent/data2/run5april26no4.txt', 'wb') as wfile:
    pickle.dump(roots_list, wfile) 

  
with open('/Users/barrybrent/data2/run5april26no5.txt', 'wb') as wfile:
    pickle.dump(mins_list, wfile)
# Out:
# j: 1
# j: 2
# j: 3
# j: 4
# j: 5
# j: 6
# j: 7
# j: 8
# j: 9
# j: 10
# j: 11
# j: 12
# j: 13
# j: 14
# j: 15
# j: 16
# j: 17
# j: 18
# j: 19
# j: 20
# j: 21
# j: 22
# j: 23
# j: 24
# j: 25
# j: 26
# j: 27
# j: 28
# j: 29
# j: 30
# j: 31
# j: 32
# j: 33
# j: 34
# j: 35
# j: 36
# j: 37
# j: 38
# j: 39
# j: 40
# j: 41
# j: 42
# j: 43
# j: 44
# j: 45
# j: 46
# j: 47
# j: 48
# j: 49
# j: 50
# j: 51
# j: 52
# j: 53
# j: 54
# j: 55
# j: 56
# j: 57
# j: 58
# j: 59
# j: 60
# j: 61
# j: 62
# j: 63
# j: 64
# j: 65
# j: 66
# j: 67
# j: 68
# j: 69
# j: 70
# j: 71
# j: 72
# j: 73
# j: 74
# j: 75
# j: 76
# j: 77
# j: 78
# j: 79
# j: 80
# j: 81
# j: 82
# j: 83
# j: 84
# j: 85
# j: 86
# j: 87
# j: 88
# j: 89
# j: 90
# j: 91
# j: 92
# j: 93
# j: 94
# j: 95
# j: 96
# j: 97
# j: 98
# j: 99
# j: 100
# j: 101
# j: 102
# j: 103
# j: 104
# j: 105
# j: 106
# j: 107
# j: 108
# j: 109
# j: 110
# j: 111
# j: 112
# j: 113
# j: 114
# j: 115
# j: 116
# j: 117
# j: 118
# j: 119
# j: 120
# j: 121
# j: 122
# j: 123
# j: 124
# j: 125
# j: 126
# j: 127
# j: 128
# j: 129
# j: 130
# j: 131
# j: 132
# j: 356
# j: 357
# j: 358
# j: 359
# j: 360
# j: 361
# j: 362
# j: 363
# j: 364
# j: 365
# j: 366
# j: 367
# j: 368
# j: 369
# j: 370
# j: 371
# j: 372
# j: 373
# j: 374
# j: 375
# j: 376
# j: 377
# j: 378
# j: 379
# j: 380
# j: 381
# j: 382
# j: 383
# j: 384
# j: 385
# j: 386
# j: 387
# j: 388
# j: 389
# j: 390
# j: 391
# j: 392
# j: 393
# j: 394
# j: 395
# j: 396
# j: 397
# j: 398
# j: 399
# j: 400
# n: 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 79
#      74 for n in range(Integer(2), Integer(351)):  # Changed to 401 to match j_list size
#      76     print("n:",n)
# ---> 79     pl = P_matrix(j_list[:n])
#      80     det = pl.det()
#      85     cp = pl.charpoly()
#
# Cell In[4], line 53, in P_matrix(lst)
#      51     column=column[:lenlist]
#      52     columns+=[column]
# ---> 53 return matrix(columns).transpose()
#
# File /var/tmp/sage-10.8-current/local/lib/python3.13/site-packages/sage/matrix/constructor.pyx:674, in sage.matrix.constructor.matrix()
#     672 """
#     673 immutable = kwds.pop('immutable', False)
# --> 674 return MatrixArgs(*args, **kwds).element(immutable=immutable)
#     675
#     676
#
# File /var/tmp/sage-10.8-current/local/lib/python3.13/site-packages/sage/matrix/args.pyx:808, in sage.matrix.args.MatrixArgs.element()
#     806     To:   Free module generated by {'u', 'v'} over Integer Ring
#     807 """
# --> 808 self.finalize()
#     809 cdef Matrix M = self.matrix(convert=True)
#     810 if immutable:
#
# File /var/tmp/sage-10.8-current/local/lib/python3.13/site-packages/sage/matrix/args.pyx:1181, in sage.matrix.args.MatrixArgs.finalize()
#    1179 # really need to look at the entries.
#    1180 if self.typ == MA_ENTRIES_SEQ_SEQ:
# -> 1181     self.finalize_seq_seq()
#    1182 elif self.typ == MA_ENTRIES_SEQ_FLAT:
#    1183     self.finalize_seq_scalar()
#
# File /var/tmp/sage-10.8-current/local/lib/python3.13/site-packages/sage/matrix/args.pyx:1424, in sage.matrix.args.MatrixArgs.finalize_seq_seq()
#    1422         self.set_ncols(c)
#    1423
# -> 1424     self.set_seq_flat(entries)
#    1425
#    1426 cdef int finalize_seq_scalar(self) except -1:
#
# File /var/tmp/sage-10.8-current/local/lib/python3.13/site-packages/sage/matrix/args.pyx:1242, in sage.matrix.args.MatrixArgs.set_seq_flat()
#    1240 """
#    1241 if self.base is None:
# -> 1242     self.set_base_from_entries(entries)
#    1243 self.entries = entries
#    1244 self.typ = MA_ENTRIES_SEQ_FLAT
#
# File /var/tmp/sage-10.8-current/local/lib/python3.13/site-packages/sage/matrix/args.pyx:1229, in sage.matrix.args.MatrixArgs.set_base_from_entries()
#    1227 """
#    1228 if entries:
# -> 1229     B = coercion_model.common_parent(*entries)
#    1230     if isinstance(B, type):
#    1231         B = py_scalar_parent(B)
#
# File /var/tmp/sage-10.8-current/local/lib/python3.13/site-packages/sage/structure/coerce.pyx:1097, in sage.structure.coerce.CoercionModel.common_parent()
#    1095     base = x
#    1096 else:
# -> 1097     a = base.an_element() if isinstance(base, Parent) else base(1)
#    1098     b = x.an_element() if isinstance(x, Parent) else x(1)
#    1099     base = parent(self.canonical_coercion(a, b)[0])
#
# TypeError: 'int' object is not iterable
