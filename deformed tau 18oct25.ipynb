# %%
# most of this cell's code was run in notebook 'primeTau1oct25no2'
from sage.all import sigma, nth_prime
from sage.arith.all import moebius
import pickle
import ast

def tau(n):
    def step1(n, k):
        return 35*k^4 - 52*k^3*n + 18*k^2*n^2
    def step2(n, k):
        return sigma(k) * sigma(n - k)
    def step3(n):
        ans = 0
        for k in range(1, n):
            ans += step1(n, k) * step2(n, k)
        return 24*ans
    return n^4 * sigma(n) - step3(n)





tau_list =[] 
for k in range(1, 501):
    tau_list.append([k,tau(k)])
    if k%100==0:
        print(k)

with open('/Users/barrybrent/data/run18oct25no13.txt', 'wb') as wfile:
    pickle.dump(tau_list, wfile) #output snipped

with open('/Users/barrybrent/data/run18oct25no13.txt', 'rb') as rfile:
    tau_list = pickle.load(rfile)
h_list=[[0,1]]+tau_list 
j_list=[(0,0)] 
for n in [1..500]:# so j(1) = 1 = h(0) as required.
    sm=0
    for r in [1..n-1]: 
        sm=sm+j_list[r][1]*h_list[n-r][1] 
    j_n=n*h_list[n][1]-sm
    j_list.append((n,j_n))

print(h_list[:10])
print()
print(j_list[:10])
    
with open('/Users/barrybrent/data/run18oct25no14.txt', 'wb') as wfile:
    pickle.dump(j_list, wfile) # ouput snipped
# Out:
# 100
# 200
# 300
# 400
# 500
# [[0, 1], [1, 1], [2, -24], [3, 252], [4, -1472], [5, 4830], [6, -6048], [7, -16744], [8, 84480], [9, -113643]]
#
# [(0, 0), (1, 1), (2, -49), (3, 829), (4, -8145), (5, 66011), (6, -583645), (7, 5566247), (8, -51805777), (9, 472068856)]

# %%
primeTau(1)
# Out:
# -24

# %%
import pickle
from sage.all import sigma, nth_prime
import ast
import time

# Increase PARI stack size to handle large polynomial root computations
pari.allocatemem(7*10^9)  # Allocate 7GB for PARI stack

def nieburTau(n):
    def step1(n, k):
        return 35*k^4 - 52*k^3*n + 18*k^2*n^2
    def step2(n, k):
        return sigma(k) * sigma(n - k)
    def step3(n):
        ans = 0
        for k in range(1, n):
            ans += step1(n, k) * step2(n, k)
        return 24*ans
    return n^4 * sigma(n) - step3(n)

def h(n):
    if n>0:
        return tau(n) # i.e., tauPrime(n)
    if n==0:
        return 1

h_list=[h(n) for n in range(0,302)]
with open('/Users/barrybrent/data/run18oct25no14.txt', 'rb') as rfile:
    j_list = pickle.load(rfile) #tauPrime(n) j-companion
    
def P_matrix(lst):
    lenlist=len(lst)
    columns=[lst]
    for k in range(1,lenlist):
        column=[0]*(k-1)
        column=column+[-k]
        column=flatten(column+[lst])
        column=column+[lst]
        column=column[:lenlist]
        columns+=[column]
    return (matrix(columns)).transpose()

def periodic_behavior_score(main_local_minima_list, min_score=0.3, max_period=100):
    """
    Analyzes periodic behavior for all v values in main_local_minima_list.
    Uses autocorrelation and FFT to detect ANY periodic pattern (not just sine waves).
    Filters out results with weak periodicity or unreasonably large periods.
    
    Args:
        main_local_minima_list: List of tuples [(v1, points1), (v2, points2), ...]
                                where points are [(x1, y1), (x2, y2), ...]
        min_score: Minimum periodicity score to accept (default: 0.3)
        max_period: Maximum allowed period (default: 100). Results with larger periods are rejected.
    
    Returns:
        results: List of tuples [(v, score, info_dict), ...] for valid results only
    """
    
    results = []
    rejected = []
    
    print("=" * 80)
    print("PERIODIC BEHAVIOR ANALYSIS RESULTS")
    print(f"(Rejecting: score < {min_score} or period > {max_period})")
    print("=" * 80)
    
    for points in mins_list:
        if len(points) < 4:
            continue
        
        # Extract x and y coordinates, converting to plain floats
        x_data = np.array([float(p[0]) for p in points])
        y_data = np.array([float(p[1]) for p in points])
        
        # Remove mean (detrend)
        y_detrended = y_data - np.mean(y_data)
        
        # --- Method 1: Autocorrelation Analysis ---
        autocorr = correlate(y_detrended, y_detrended, mode='full')
        autocorr = autocorr[len(autocorr)//2:]
        autocorr = autocorr / autocorr[0]  # Normalize
        
        # Find peaks in autocorrelation (excluding the first peak at lag=0)
        peaks, properties = find_peaks(autocorr[1:], prominence=0.1, distance=3)
        peaks = peaks + 1  # Adjust for excluding first element
        
        # Calculate periodicity score from autocorrelation
        if len(peaks) > 0:
            autocorr_score = autocorr[peaks[0]] if peaks[0] < len(autocorr) else 0
            spacing = np.mean(np.diff(x_data))
            autocorr_period = peaks[0] * spacing
        else:
            autocorr_score = 0
            autocorr_period = None
        
        # --- Method 2: FFT Analysis ---
        n = len(y_detrended)
        yf = fft(y_detrended)
        spacing = np.mean(np.diff(x_data))
        xf = fftfreq(n, spacing)[:n//2]
        power = 2.0/n * np.abs(yf[:n//2])
        
        if len(power) > 1:
            dominant_freq_idx = np.argmax(power[1:]) + 1
            dominant_freq = xf[dominant_freq_idx]
            fft_period = 1/dominant_freq if dominant_freq > 0 else None
            
            # FFT score: ratio of dominant peak to mean power
            mean_power = np.mean(power[1:])
            fft_score = power[dominant_freq_idx] / mean_power if mean_power > 0 else 0
            fft_score = min(fft_score / 10, 1.0)  # Normalize to 0-1 range
        else:
            fft_period = None
            fft_score = 0
            dominant_freq = 0
        
        # --- Combined Score ---
        combined_score = (autocorr_score + fft_score) / 2
        
        # Determine best period estimate
        if autocorr_period and fft_period:
            # Use autocorr period if both are available and similar
            if abs(autocorr_period - fft_period) / max(autocorr_period, fft_period) < 0.3:
                best_period = autocorr_period
                period_confidence = "high"
            else:
                # Use the one with higher score
                best_period = autocorr_period if autocorr_score > fft_score else fft_period
                period_confidence = "moderate"
        elif autocorr_period:
            best_period = autocorr_period
            period_confidence = "moderate"
        elif fft_period:
            best_period = fft_period
            period_confidence = "low"
        else:
            best_period = None
            period_confidence = "none"
        
        # Check rejection criteria
        rejection_reason = None
        if combined_score < min_score:
            rejection_reason = f"score = {combined_score:.3f} (too low)"
        elif best_period and best_period > max_period:
            rejection_reason = f"period = {best_period:.2f} (too large)"
        
        if rejection_reason:
            print(f"\nREJECTED v = {v}: {rejection_reason}")
            print(f"  ({len(peaks)} autocorrelation peaks found)")
            rejected.append((v, combined_score, best_period))
            continue
        
        # Package results
        info_dict = {
            'combined_score': combined_score,
            'autocorr_score': autocorr_score,
            'autocorr_period': autocorr_period,
            'autocorr_peaks': len(peaks),
            'fft_score': fft_score,
            'fft_period': fft_period,
            'dominant_frequency': dominant_freq,
            'best_period': best_period,
            'period_confidence': period_confidence
        }
        
        results.append((v, combined_score, info_dict))
        
        print(f"\nAnalyzing v = {v}:")
        print(f"  Autocorrelation peaks found: {len(peaks)}")
        print(f"  Combined periodicity score = {combined_score:.6f}")
        print(f"  Best period estimate = {best_period:.4f} (confidence: {period_confidence})")
        print(f"  Autocorrelation: score = {autocorr_score:.4f}, period = {(autocorr_period if autocorr_period else 0):.4f}")
        print(f"  FFT: score = {fft_score:.4f}, period = {(fft_period if fft_period else 0):.4f}")
        print(f"  Dominant frequency = {dominant_freq:.6f}")
    
    print("\n" + "=" * 80)
    print(f"ANALYSIS COMPLETE: {len(results)} valid results, {len(rejected)} rejected")
    print("=" * 80)
    
    return results

from sage.all import *
precision_bits = 100
CC = ComplexField(precision_bits)
x = polygen(QQ)  # Can remain in preamble if all polynomials are in one variable
matrix_list=[]
charpol_list=[]
roots_list=[]
aar_list=[]
centers_list=[]
max_diameter_list=[]
mins_list=[]
log_mins_list=[]
maxes_list=[]
log_maxes_list=[]
dets=[]
tests=[]
for n in range(1, 201):
    print("----------------------------------------------------------------------------------------------------")
    deformed_j_list=j_list[:n]
    inputs=[pair[1] for pair in deformed_j_list]
    pl=P_matrix(inputs) ### DEFORMED
    det=pl.det()
    test=det-h_list[n]*factorial(n)
    tests.append(test)
    print((n,test,time.time()))
    dets.append((n,det))
    matrix_list+=[(n,pl)]
    cp=pl.charpoly()
    charpol_list+=[(n,cp)]
    roots = cp.roots(ring=CC, multiplicities=False)       
    roots_list+=[(n,roots)]
    pairs = [(z.real(), z.imag()) for z in roots]
    aar = [r.abs() for r in roots]
    aar_list+=[(n,aar)]
    # compute absolute value for each root (before any conversion)
    if aar!=[]:
        minn = min(aar)  
        mins_list+=[(n,minn)]
        mins_list.append((n,minn))
        if minn>0:
            log_minn=log(minn)
            log_mins_list.append((n,log_minn))
        maxx = max(aar)  
        maxes_list.append((n,maxx))
        
    if n%50==0:
        p = list_plot(mins_list, plotjoined=True, axes_labels=['', ''])
        print("MINIMUM MODULI")
        p.show()
        p = list_plot(log_mins_list, plotjoined=True, axes_labels=['', ''])
        print("LOGS MINIMUM MODULI")
        p.show()
        mml=[pair[1] for pair in log_mins_list]
        print("minimum logarithm of minimum modulus:",min(mml))
        p = list_plot(maxes_list, plotjoined=True, axes_labels=['', ''])
        print("MAXIMUM MODULI")
        p.show()
    results = periodic_behavior_score(mins_list, min_score=0.3, max_period=100)

with open('/Users/barrybrent/data/run18oct25no 120.txt', 'wb') as wfile:
    pickle.dump(roots_list, wfile) #output snipped

with open('/Users/barrybrent/data/run18oct25no121.txt', 'wb') as wfile:
    pickle.dump(charpol_list, wfile) #output snipped

with open('/Users/barrybrent/data/run18oct25no122.txt', 'wb') as wfile:
    pickle.dump(dets, wfile) #output snipped
    
with open('/Users/barrybrent/data/run18oct25no123.txt', 'wb') as wfile:
    pickle.dump(log_mins_list, wfile) #output snipped

with open('/Users/barrybrent/data/run18oct25no124.txt', 'wb') as wfile:
    pickle.dump(maxes_list, wfile) #output snipped

from sage.plot.colors import rainbow
import matplotlib.pyplot as plt

n_values = [n for n, roots in roots_list]
n_min, n_max = min(n_values), max(n_values)
colors = rainbow(len(n_values))

# Collect all points with their n values for matplotlib
all_points = []
all_n_values = []
for n, roots in roots_list:
    for z in roots:
        all_points.append((float(z.real()), float(z.imag())))
        all_n_values.append(n)

# Use matplotlib for better color mapping
real_parts = [p[0] for p in all_points]
imag_parts = [p[1] for p in all_points]

plt.scatter(real_parts, imag_parts, c=all_n_values, cmap='rainbow', s=1)
plt.colorbar(label='n')
plt.xlabel('Real')
plt.ylabel('Imaginary')
plt.title('Roots colored by n')
plt.show()
# Out:
# PARI stack size set to 7000000000 bytes, maximum size set to 7000002560
# ----------------------------------------------------------------------------------------------------
# (1, -1, 1760823111.70308)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (2, 49, 1760823111.759338)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (3, -1610, 1760823111.776767)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (4, 40305, 1760823111.8059552)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (5, -776060, 1760823111.808376)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (6, 12446545, 1760823111.812355)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (7, -357010830, 1760823111.815191)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (8, 26811899905, 1760823111.8186638)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (9, -2251370287160, 1760823111.822092)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (10, 191210789081025, 1760823111.825731)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (11, -17735161723329050, 1760823111.8296802)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (12, 1818368706902539825, 1760823111.834477)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (13, -203088198068780854500, 1760823111.840193)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (14, 24509897770307875836625, 1760823111.846721)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (15, -3183852690103478640412550, 1760823111.8542058)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (16, 443033844229540229602154625, 1760823111.862019)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (17, -65716376363590362778145346800, 1760823111.877009)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (18, 10350628594945871831512972545025, 1760823111.886755)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (19, -1725427541807312083748359245248850, 1760823111.898931)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (20, 303495883082529904709028036848544625, 1760823111.914151)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (21, -56173760616700768480769764505479809500, 1760823111.9300961)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (22, 10913510331223375727003767494460977020625, 1760823111.947943)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (23, -2220634673412104994621162300491354235770750, 1760823111.96786)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (24, 472264798102369800503936498216689987666314625, 1760823111.99579)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (25, -104779660421753762929822391433487848690756345000, 1760823112.029907)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (26, 24210574986451796018167709954411943230091843090625, 1760823112.057208)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (27, -5816776068063171423665106914436088215519081527626250, 1760823112.085387)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (28, 1451017127737464363328471494310064552149115129607800625, 1760823112.119241)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (29, -375305891973102216293745455852653535452952615977008252500, 1760823112.153897)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (30, 100524475897721500335909626611551457414199519494927753740625, 1760823112.189158)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (31, -27849657364633080586417197236715080923608758383428620566293750, 1760823112.229321)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (32, 7971699313167727589862307684129940442139682201936259331044090625, 1760823112.270068)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (33, -2355139404687335571609024939000529614130342021223197469391248300000, 1760823112.311697)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (34, 717457365526736542193155895784814527936125643518668816984576505690625, 1760823112.357352)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (35, -225161162410120783292621902577390285940444859015909849422137179362781250, 1760823112.418048)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (36, 72733712578981911761975341559294575337317520781002217227349137699708640625, 1760823112.473836)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (37, -24164111794817028625894197220484593619524950829208658680211978088973563687500, 1760823112.52958)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (38, 8250226210077513508842530377945419107182783764621103278035952654736176964140625, 1760823112.5875142)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (39, -2892714926380335242339284412559286128810106979146786800317501200908331311303968750, 1760823112.650465)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (40, 1040857581996946812673360089654812190498331144708082684090201502109550919665688890625, 1760823112.718152)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (41, -384095385908293882723137571618674664488128794041784597964903277284373643204857119375000, 1760823112.803475)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (42, 145271076827133122604923035802420465296361046891170753981671039606463321199690728923890625, 1760823112.879492)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (43, -56280072351031989178396824301308413449290632238335024928233890571886916954918993409970656250, 1760823112.966551)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (44, 22321365180297613412604993112106146559668198423993821804091225238912230897907695143934103640625, 1760823113.057627)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (45, -9058241220607984338119922101408093272256425259098028438770457182379689988996582221385298866562500, 1760823113.149138)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (46, 3759247420034601645713116913467746000698050406419199412141041182076571481098782492295951629634140625, 1760823113.2632031)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (47, -1594698159949613098825103928204403599740694440186080764085661008098951061767941739747722592937874843750, 1760823113.364216)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (48, 691150194467455218824409476634351394752735089862685396063369728069812913648632837368677059266603282890625, 1760823113.475904)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (49, -305905378415131862971150170331396175983274793613223269527608799645760006491032673913106340442188019481250000, 1760823113.60415)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (50, 138208562801797416954040730412353398392739441966743643176603346343715284399250211307125202009167867525612890625, 1760823113.7247229)
# MINIMUM MODULI
# Graphics object consisting of 1 graphics primitive
# LOGS MINIMUM MODULI
# Graphics object consisting of 1 graphics primitive
# minimum logarithm of minimum modulus: 0.00000000000000000000000000000
# MAXIMUM MODULI
# Graphics object consisting of 1 graphics primitive
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (51, -63714155406151608002587110685433293123031750808168627715900915246095022503639041809193769682189456161547144531250, 1760823115.3987331)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (52, 29958298537669557039014605147578457505373313811806203572069476586500981071898499661409203519075983975486870956640625, 1760823115.547787)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (53, -14361916010422890832696391803443393032111716817229851447921675232832593687833167151762167960226748188374580463223437500, 1760823115.700466)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (54, 7017166026354547878375550845795530765222752843170443679525078406353463091328314908243361355993369918612354504716794140625, 1760823115.866373)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (55, -3493102438891277526046909702762835119801717836480877796965065409108536116693839803846547702701530373891194352400467011718750, 1760823116.04893)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (56, 1770976494721477770910794912093105485205562440790322390674193215153678586518797774180458206529679836402391791548686328462890625, 1760823116.238522)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (57, -914162103439226547485150884446725111059218742250435017226309844206915711774329683508307138735576967637621112916923401303953125000, 1760823116.430565)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (58, 480291230719725428135449259731837715314336840669593194670388696684500177467830286258721053715710884183569586289558297149095087890625, 1760823116.644798)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (59, -256758009170693250165540147726768708343118642285002965874704154218175050859472002869667711367072239256729410463333461300482281316406250, 1760823116.890595)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (60, 139621613995355629339091109755794113574816068833030231341190310251168376431541006371202576232733472448292406811727045539465955389931640625, 1760823117.143348)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (61, -77208718963189453089273216724365393424531681226784182747598713299036645423051285884927849370130128829486874139358385126634213740934570312500, 1760823117.4008372)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (62, 43405514017408428487459623070524472358850587163512829510803550719220092480052521821791440855211756342917038324440412764877088353294005244140625, 1760823117.666471)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (63, -24801163216719742018640513861433978145119727065058888014639774330068246741017231618615410555491930593705494463226583169228218554397015620058593750, 1760823117.9283662)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (64, 14399095975816795060324183782937577862620982236114867828518023430787239966393035166745340111410916453030044689752716109012446456278140557833212890625, 1760823118.206544)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (65, -8492301588909455758802411753505624605225732089479184547685796598429213072258394750719481848826982772263277997551422364236384621114679855607254375000000, 1760823118.53967)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (66, 5086709655276728131207717491715526260931196200585914588853219814906652592495265821608075477323740971829898591386368099181758025961310530537980468212890625, 1760823118.890623)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (67, -3093623215974472310035201937391029453114184383883454247048317534874359798267522941039176219558334495220850071568804020652996830102463462214018118439238281250, 1760823119.233568)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (68, 1909930050062456791299135514604252977764778610759488038497499360152399902052424263776311802580799516726852822159488270294511942845409871935763801430455556640625, 1760823119.588806)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (69, -1196714805507617475011558849540268131702353543872888370724035632719989021773782211522062334462079314578401808419994409657299522719893536626431147882894653867187500, 1760823119.972308)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (70, 760840144098093359402220502820131668034162858619175387322156703533250503024608848829840624048053542303968931623203038195527919568234969128420597209143221062744140625, 1760823120.3846872)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (71, -490721187982193374791799029344345432214241470201356021796252175895865858351253830592525340693255336267858797310151198029188078751923886877096329935707980492576855468750, 1760823120.799673)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (72, 321015863521635984414671623804204681107292371761021572295142493315422127449724418714749428525118721319048282677374232281872776665804493005287357640122951027624443212890625, 1760823121.229474)
# ...
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (175, -..., 1760823543.217129)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (176, ..., 1760823555.88644)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (177, -..., 1760823568.031649)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (178, ..., 1760823581.10285)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (179, -..., 1760823594.717678)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (180, ..., 1760823608.8607519)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (181, -..., 1760823622.010489)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (182, ..., 1760823636.66527)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (183, -..., 1760823651.757848)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (184, ..., 1760823666.975987)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (185, -..., 1760823681.367805)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (186, ..., 1760823697.615634)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (187, -..., 1760823713.9425988)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (188, ..., 1760823730.843668)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (189, -..., 1760823746.801731)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (190, ..., 1760823764.28651)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (191, -..., 1760823781.9812968)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (192, ..., 1760823799.887564)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (193, -..., 1760823818.519263)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (194, ..., 1760823837.5526211)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (195, -..., 1760823856.714062)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (196, ..., 1760823876.566315)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (197, -..., 1760823895.074624)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (198, ..., 1760823915.4627168)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (199, -..., 1760823936.333449)
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================
# ----------------------------------------------------------------------------------------------------
# (200, ..., 1760823957.755865)
# MINIMUM MODULI
# Graphics object consisting of 1 graphics primitive
# LOGS MINIMUM MODULI
# Graphics object consisting of 1 graphics primitive
# minimum logarithm of minimum modulus: 0.00000000000000000000000000000
# MAXIMUM MODULI
# Graphics object consisting of 1 graphics primitive
# ================================================================================
# PERIODIC BEHAVIOR ANALYSIS RESULTS
# (Rejecting: score < 0.300000000000000 or period > 100)
# ================================================================================
#
# ================================================================================
# ANALYSIS COMPLETE: 0 valid results, 0 rejected
# ================================================================================

# %%
with open('/Users/barrybrent/data/run18oct25no124.txt', 'wb') as wfile:
    pickle.dump(maxes_list, wfile) #output snipped

with open('/Users/barrybrent/data/run18oct25no125.txt', 'wb') as wfile:
    pickle.dump(mins_list, wfile) #output snipped
