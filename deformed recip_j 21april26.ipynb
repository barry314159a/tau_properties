q^46 + 98179332763804157186647523791690465702841789878305833738423319749305851170312448656295366848852960076399248269369344000*q^47 - 23624938169547569091946205031804734624016882706502313003232018030894388821366104206197733237490194081155036654885404672000*q^48 + 5680002071373751638523175430554197899205078114072476062116285756613296759083261797250091651980681736142799489487498962432000*q^49 - 1364484157783451796766224168790890419455616256630319965717212717271753874537488933907814248112163821142175984139516867481600000*q^50 + 327525250118692785907560380003086909736165944268307246068317562365348903423954345212705569949346896994694585559102498165362688000*q^51 - 78558040218368217434212746887816053402879878995214243844043199236395197890200 ...
#
# Elapsed: 0.011764049530029297

# %%
import pickle
from sage.all import *
import time

start = time.time()

R.<q> = PowerSeriesRing(QQ, default_prec=3000)

E4 = eisenstein_series_qexp(4, 3000, K=QQ)
Delta = delta_qexp(3000)

j = E4^3 / Delta



recip_j = 1 / j



recip_j_list =[] 
for k in range(1, 2800):
    recip_j_list.append([k,recip_j[k]])
    if k%50==0:
        print("recip_j",k)

with open('/Users/barrybrent/data2/run21april26no1.txt', 'wb') as wfile:
    pickle.dump(recip_j_list, wfile) #output snipped

short=recip_j_list[:20]
print(short)
recip_j_on_primes=[pair for pair in recip_j_list if is_prime(pair[0])]
short_primes=recip_j_on_primes[:10]
print()
print(short_primes)

h_list=[(0,1)]+recip_j_on_primes 
h_vals=[pair[1] for pair in h_list]
j_list=[(0,1)] 
for n in range(1,401):
    sm=0
    for r in [1..n-1]: 
        sm=sm+j_list[r][1]*h_vals[n-r]
    j_n=n*h_list[n][1]-sm
    j_list.append((n,j_n))
    if n%100==0:
        print("j_list:",n)

    
with open('/Users/barrybrent/data2/run21april26no2.txt', 'wb') as wfile:
    pickle.dump(j_list, wfile) # ouput snipped

now=time.time()
print("elapsed seconds:",now-start)
# Out:
# recip_j 50
# recip_j 100
# recip_j 150
# recip_j 200
# recip_j 250
# recip_j 300
# recip_j 350
# recip_j 400
# recip_j 450
# recip_j 500
# recip_j 550
# recip_j 600
# recip_j 650
# recip_j 700
# recip_j 750
# recip_j 800
# recip_j 850
# recip_j 900
# recip_j 950
# recip_j 1000
# recip_j 1050
# recip_j 1100
# recip_j 1150
# recip_j 1200
# recip_j 1250
# recip_j 1300
# recip_j 1350
# recip_j 1400
# recip_j 1450
# recip_j 1500
# recip_j 1550
# recip_j 1600
# recip_j 1650
# recip_j 1700
# recip_j 1750
# recip_j 1800
# recip_j 1850
# recip_j 1900
# recip_j 1950
# recip_j 2000
# recip_j 2050
# recip_j 2100
# recip_j 2150
# recip_j 2200
# recip_j 2250
# recip_j 2300
# recip_j 2350
# recip_j 2400
# recip_j 2450
# recip_j 2500
# recip_j 2550
# recip_j 2600
# recip_j 2650
# recip_j 2700
# recip_j 2750
# [[1, 13824000], [2, -10285056000], [3, 4930357248000], [4, -1940352565248000], [5, 682030294594560000], [6, -222768585249472512000], [7, 69106763207998623744000], [8, -20634661565591247912960000], [9, 5982512387118126001049088000], [10, -1694362076510094122103152640000], [11, 470822826897730914905696606208000], [12, -128779262032847164677324976029696000], [13, 34757473409763317268070465655129088000], [14, -9274829468038449406345417902141505536000], [15, 2450696287760358195439193563082113413120000], [16, -642009581183376917706793805641930701275136000], [17, 166919628277379870918051134764458661644012544000], [18, -43107945910425906461367151527583937097151721472000], [19, 11066293582161088684906679701411680836049108264960000], [20, -2825567439798646859951613842426574036377076550533120000]]
#
# [[2, -10285056000], [3, 4930357248000], [5, 682030294594560000], [7, 69106763207998623744000], [11, 470822826897730914905696606208000], [13, 34757473409763317268070465655129088000], [17, 166919628277379870918051134764458661644012544000], [19, 11066293582161088684906679701411680836049108264960000], [23, 45758693114653796914042071845830113344089800671595454230528000], [29, 10932145978369640495478535880032831056759394929356763187845866288140477440000]]
# j_list: 100
# j_list: 200
# j_list: 300
# j_list: 400
# elapsed seconds: 1.2845299243927002

# %%
import pickle
from sage.all import sigma, nth_prime
import ast
import time

start=time.time()
with open('/Users/barrybrent/data2/run21april26no2.txt', 'rb') as rfile:
    j_list = pickle.load(rfile)
    
def P_matrix(lst):
    lenlist=len(lst)
    columns=[lst]
    for k in range(1,lenlist):
        column=[0]*(k-1)
        column=column+[-k]
        column=flatten(column+[lst])
        column=column+[lst]
        column=column[:lenlist]
        columns+=[column]
    return (matrix(columns)).transpose()

from sage.all import *
precision_bits = 100
CC = ComplexField(precision_bits)
x = polygen(QQ)  # Can remain in preamble if all polynomials are in one variable

charpol_list=[]
roots_list=[]

mins_list=[]
log_mins_list=[]

dets=[]

for n in range(2, 301):
    now=time.time()
    print(n,(now-start)/60)
    deformed_j_list=j_list[1:n]#<<<<<<<<<<<<<<<<<<<<<<<< undeformed
    inputs=[pair[1] for pair in deformed_j_list]
    pl=P_matrix(inputs) 
    det=pl.det()
    dets.append((n,det))
    cp=pl.charpoly()
    charpol_list.append((n,cp))
    roots = cp.roots(ring=CC, multiplicities=False)       
    roots_list.append((n,roots))
    aar = [r.abs() for r in roots]
    if aar!=[]:
        minn = min(aar)  
        mins_list.append((n,minn))
        
        

    if n%20==0:
        p = list_plot(mins_list, plotjoined=True, axes_labels=['', ''])
        print("MINIMUM MODULI")
        p.show()

p = list_plot(mins_list, plotjoined=True, axes_labels=['', ''])
print("MINIMUM MODULI")
p.show()

with open('/Users/barrybrent/data2/run17aprilr26no3.txt', 'wb') as wfile:
    pickle.dump(roots_list, wfile) #output snipped

with open('/Users/barrybrent/data2/run17april26no4.txt', 'wb') as wfile:
    pickle.dump(charpol_list, wfile) #output snipped

with open('/Users/barrybrent/data2/run17april26no5.txt', 'wb') as wfile:
    pickle.dump(mins_list, wfile) #output snipped
# Out:
# 2 0.0002642353375752767
# 3 0.0014685670534769694
# 4 0.001526049772898356
# 5 0.0016349037488301596
# 6 0.0021564682324727376
# 7 0.0022057175636291506
# 8 0.0022458871205647784
# 9 0.0023064692815144856
# 10 0.0023705005645751954
# 11 0.0024442354838053386
# 12 0.0025353511174519856
# 13 0.0026586333910624186
# 14 0.0027880509694417316
# 15 0.0029638210932413736
# 16 0.003204782803853353
# 17 0.003553338845570882
# 18 0.003871432940165202
# 19 0.004258684317270915
# 20 0.004691569010416666
# MINIMUM MODULI
# Graphics object consisting of 1 graphics primitive
# 21 0.025060653686523438
# 22 0.025722519556681315
# 23 0.02644695043563843
# 24 0.027232937018076577
# 25 0.028128981590270996
# 26 0.02923056681950887
# 27 0.030513652165730796
# 28 0.031872053941090904
# 29 0.03357343276341756
# 30 0.035966734091440834
# 31 0.039039584000905354
# 32 0.042719686031341554
# 33 0.046026368935902916
# 34 0.04955461819966634
# 35 0.05382870435714722
# 36 0.058447452386220296
# 37 0.06377571821212769
# 38 0.0696489691734314
# 39 0.07716848452885945
# 40 0.08489565054575603
# MINIMUM MODULI
# Graphics object consisting of 1 graphics primitive
# MINIMUM MODULI
# Graphics object consisting of 1 graphics primitive
# 181 562.8055190682411
# 182 582.6796046535175
# 183 603.1125892202059
# 184 624.0475064516068
# 185 645.4897818168005
# 186 667.7254796187083
# 187 690.6129034678141
# 188 713.8422981858254
# 189 737.9389375686645
# 190 762.5079821387927
# 191 787.8097697854042
# 192 813.8437848846118
# 193 840.5503605008125
# 194 868.5834698518117
# 195 896.8315462668737
# 196 925.8601657191913
# 197 955.7289228876432
# 198 986.5292647520702
# 199 1017.923167749246
# 200 1050.2480450550715
# MINIMUM MODULI
# Graphics object consisting of 1 graphics primitive
# 201 1083.0256037513416
# 202 1117.2145563205083
# 203 1153.419372900327
# 204 1186.4795241713523
# 205 1219.9936348001163
# 206 1254.3017722686131
# 207 1291.2792878349621
# 208 1331.1136453191439
# 209 1371.9346901337306
# 210 1414.0659909009933
# 211 1457.0071513374646
# 212 1500.7569628516833
# 213 1545.666346581777
# 214 1591.674832868576
# 215 1635.7474005699157
# 216 1683.5850311199824
# 217 1732.4356191158295
# 218 1782.1842216332755
# 219 1833.77755925258
# 220 1886.873458703359
# MINIMUM MODULI
# Graphics object consisting of 1 graphics primitive
# 221 1941.0826146999996
# 222 1996.8563863356908
# 223 2051.7342928528788
# 224 2110.7494092345237
# 225 2171.443079618613
# 226 2233.3619131843247
# 227 2296.520812900861
# 228 2360.8798387328784
# 229 2427.2840985178946
# 230 2494.949760035674
# 231 2564.2585819681485
# 232 2630.445746485392
# 233 2699.2298533876738
# 234 2773.0269376715023
# 235 2846.9528103192647
# 236 2922.734401468436
# 237 2997.5839497009915
# 238 3075.4025872866314
# 239 3157.409716685613
# 240 3238.703338134289
# MINIMUM MODULI
# Graphics object consisting of 1 graphics primitive
# 241 3324.27095905145
# 242 3411.347039985657
# 243 3495.905855667591
# 244 3587.41734470129
# 245 3680.559777069092
# 246 3775.5678546031318
# 247 3872.5490593512855
# 248 3971.516670835018
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 41
#      39 inputs=[pair[Integer(1)] for pair in deformed_j_list]
#      40 pl=P_matrix(inputs)
# ---> 41 det=pl.det()
#      42 dets.append((n,det))
#      43 cp=pl.charpoly()
#
# File /var/tmp/sage-10.8-current/local/lib/python3.13/site-packages/sage/matrix/matrix2.pyx:2229, in sage.matrix.matrix2.Matrix.det()
#    2227         6
#    2228     """
# -> 2229     return self.determinant(*args, **kwds)
#    2230
#    2231 def determinant(self, algorithm=None):
#
# File /var/tmp/sage-10.8-current/local/lib/python3.13/site-packages/sage/matrix/matrix_rational_dense.pyx:881, in sage.matrix.matrix_rational_dense.Matrix_rational_dense.determinant()
#     879
#     880         if algorithm is None or algorithm == "flint":
# --> 881             det = self._det_flint()
#     882         elif algorithm == "pari":
#     883             det = self._det_pari()
#
# File /var/tmp/sage-10.8-current/local/lib/python3.13/site-packages/sage/matrix/matrix_rational_dense.pyx:913, in sage.matrix.matrix_rational_dense.Matrix_rational_dense._det_flint()
#     911 cdef fmpq_t e
#     912 fmpq_init(e)
# --> 913 sig_on()
#     914 fmpq_mat_det(e, self._matrix)
#     915 fmpq_get_mpq(d.value, e)
#
# KeyboardInterrupt:

# %%
with open('/Users/barrybrent/data2/run17april26no5.txt', 'wb') as wfile:
    pickle.dump(mins_list, wfile) #output snipped

# %%
with open('/Users/barrybrent/data2/run17aprilr26no3.txt', 'wb') as wfile:
    pickle.dump(roots_list, wfile) #output snipped

with open('/Users/barrybrent/data2/run17april26no4.txt', 'wb') as wfile:
    pickle.dump(charpol_list, wfile) #output snipped

with open('/Users/barrybrent/data2/run17april26no5.txt', 'wb') as wfile:
    pickle.dump(mins_list, wfile) #output snipped
