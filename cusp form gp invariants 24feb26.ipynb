# %%
# ==============================================================================
# COMPLETE ELLIPTIC CURVE + DELTA INVARIANT COLLECTOR
# Outputs:
#   1. CSV file
#   2. Booktabs LaTeX table
#   3. Longtable LaTeX table
# ==============================================================================

import csv
from datetime import datetime
from sage.all import *

# ==============================================================================
# CONFIGURATION
# ==============================================================================

conductor_bound = 54
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")

csv_filename        = f"curve_data_{conductor_bound}_{timestamp}.csv"
latex_booktabs_file = f"curve_table_booktabs_{conductor_bound}_{timestamp}.tex"
latex_long_file     = f"curve_table_long_{conductor_bound}_{timestamp}.tex"

# ==============================================================================
# HELPER FUNCTIONS
# ==============================================================================

def torsion_string(E):
    T = E.torsion_subgroup().invariants()
    if len(T) == 0:
        return "0"
    return r"$" + r" \times ".join(
        [rf"\mathbb{{Z}}/{n}\mathbb{{Z}}" for n in T]) + r"$"

def ap_string(E, k=10):
    plist = list(primes_first_n(k))
    return "|".join([f"a_{p}={E.ap(p)}" for p in plist])

def tau_string(k=10):
    plist = list(primes_first_n(k))
    return "|".join([f"tau({p})={ramanujan_tau(p)}" for p in plist])

def gamma0_data(N):
    G = Gamma0(N)
    return G.index(), G.genus(), G.ncusps()

# ==============================================================================
# BUILD DATA
# ==============================================================================

rows = []

# ---- Delta row ----
rows.append({
    "label": r"$\Delta$",
    "N": 1,
    "weight": 12,
    "rank": "---",
    "torsion": "---",
    "CM": "N",
    "root": "+1",
    "osc_all": "",
    "osc_pr": ""
})

# ---- Elliptic curves ----
for N in range(1, conductor_bound+1):
    try:
        curves = cremona_curves([N])
    except:
        continue

    for Ec in curves:
        E = EllipticCurve(Ec.label())

        try:
            rank = E.rank()
        except:
            rank = "?"

        try:
            root = "+1" if E.root_number() == 1 else "-1"
        except:
            root = "?"

        rows.append({
            "label": Ec.label(),
            "N": N,
            "weight": 2,
            "rank": rank,
            "torsion": torsion_string(E),
            "CM": "Y" if E.has_cm() else "N",
            "root": root,
            "osc_all": "",
            "osc_pr": ""
        })

# ==============================================================================
# WRITE CSV
# ==============================================================================

with open(csv_filename, 'w', newline='') as f:
    writer = csv.DictWriter(f, fieldnames=rows[0].keys())
    writer.writeheader()
    writer.writerows(rows)

print("CSV written:", csv_filename)

# ==============================================================================
# GENERATE BOOKTABS TABLE
# ==============================================================================

booktabs_lines = []

booktabs_lines.append(r"\begin{table}[htbp]")
booktabs_lines.append(r"\centering")
booktabs_lines.append(r"\small")
booktabs_lines.append(
    rf"\caption{{Arithmetic invariants for $\Delta$ and weight-2 newforms "
    rf"of conductor $N \le {conductor_bound}$.}}")
booktabs_lines.append(rf"\label{{tab:curve_groups_{conductor_bound}}}")
booktabs_lines.append(r"\begin{tabular}{ccccccccc}")
booktabs_lines.append(r"\toprule")
booktabs_lines.append(
    r"Curve & $N$ & Wt & Rank & Torsion & CM & Root & "
    r"Osc.\,(all) & Osc.\,(pr) \\")
booktabs_lines.append(r"\midrule")

for r in rows:
    line = " & ".join([str(r[k]) for k in r])
    booktabs_lines.append(line + r" \\")

booktabs_lines.append(r"\bottomrule")
booktabs_lines.append(r"\end{tabular}")
booktabs_lines.append(r"\end{table}")

with open(latex_booktabs_file, 'w') as f:
    f.write("\n".join(booktabs_lines))

print("Booktabs LaTeX written:", latex_booktabs_file)

# ==============================================================================
# GENERATE LONGTABLE VERSION
# ==============================================================================

long_lines = []

long_lines.append(r"\small")
long_lines.append(r"\begin{longtable}{ccccccccc}")
long_lines.append(
    rf"\caption{{Arithmetic invariants for $\Delta$ and weight-2 newforms "
    rf"of conductor $N \le {conductor_bound}$.}} \\")
long_lines.append(r"\toprule")
long_lines.append(
    r"Curve & $N$ & Wt & Rank & Torsion & CM & Root & "
    r"Osc.\,(all) & Osc.\,(pr) \\")
long_lines.append(r"\midrule")
long_lines.append(r"\endfirsthead")

long_lines.append(r"\toprule")
long_lines.append(
    r"Curve & $N$ & Wt & Rank & Torsion & CM & Root & "
    r"Osc.\,(all) & Osc.\,(pr) \\")
long_lines.append(r"\midrule")
long_lines.append(r"\endhead")

long_lines.append(r"\bottomrule")
long_lines.append(r"\endfoot")

for r in rows:
    line = " & ".join([str(r[k]) for k in r])
    long_lines.append(line + r" \\")

long_lines.append(r"\end{longtable}")

with open(latex_long_file, 'w') as f:
    f.write("\n".join(long_lines))

print("Longtable LaTeX written:", latex_long_file)

print("DONE.")
# Out:
# CSV written: curve_data_54_20260224_144159.csv
# Booktabs LaTeX written: curve_table_booktabs_54_20260224_144159.tex
# Longtable LaTeX written: curve_table_long_54_20260224_144159.tex
# DONE.
