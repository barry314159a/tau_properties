# %%
from sage.all import sigma, nth_prime
import pickle
import ast

tau_list = []

with open('/Users/barrybrent/data/tauUpTo10^5', 'r') as rfile:
    for line in rfile:
        line = line.strip()
        if line:  # skip empty lines
            # Replace Mathematica braces with Python brackets
            line = line.replace("{", "[").replace("}", "]")
            # Convert to Python list
            tau_list.append(ast.literal_eval(line))
#tau_list was made in the Mathematica notebook
# "tauTo10^5maker Lehmer mthd.nb
# the code to convert the Mathematica file to Python was made by chatGPT


s_list=[0,1] # so j(0) = 0, harmless, and j(1) = 1, per lemma 2.2
for n in [2..500]:
    print("making s_list",n)
    s_n=sigma(n)
    s_list.append(s_n)
    
with open('/Users/barrybrent/data/run29sept25no1.txt', 'wb') as wfile:
    pickle.dump(s_list, wfile) #output snipped

# %%
ls=[2,3,5]
ls[1:]
# Out:
# [3, 5]

# %%
# try to correct the offset
def P_matrix(lst):
    lenlist=len(lst)
    columns=[lst]
    for k in range(1,lenlist):
        column=[0]*(k-1)
        column=column+[-k]
        column=flatten(column+[lst])
        column=column+[lst]
        column=column[:lenlist]
        columns+=[column]
    return (matrix(columns)).transpose()

import pickle
with open('/Users/barrybrent/data/run29sept25no1.txt', 'rb') as rfile:
    s_list = pickle.load(rfile)
j_list=s_list[1:]
from sage.all import *
from sage.combinat.partition import number_of_partitions as partition_number
precision_bits = 100
CIF = ComplexIntervalField(precision_bits)
x = polygen(QQ)  # Can remain in preamble if all polynomials are in one variable
matrix_list=[]
charpol_list=[]
roots_list=[]
aar_list=[]
centers_list=[]
max_diameter_list=[]
mins_list=[]
log_mins_list=[]
no=[]
for bound in range(2,10):
    lst=j_list[:bound]
    inpt=[j for j in lst]
    pl=P_matrix(inpt)
    matrix_list+=[(bound,pl)]
    cp=pl.charpoly()
    charpol_list+=[(bound,cp)]
    roots = cp.roots(ring=CIF, multiplicities=False)        # produces list of roots as Sage objects
    roots_list+=[(bound,roots)]
    centers=[r.center() for r in roots]
    pairs = [(z.real(), z.imag()) for z in centers]

# Plot the points (no lines, small points, only axis ticks)
    p = list_plot(pairs, plotjoined=False, pointsize=10, axes_labels=['', ''])
    #p.show()
    centers_list+=[(bound,centers)]
    max_diameter=max([r.diameter() for r in roots])
    max_diameter_list+=[(bound,max_diameter)]
    aar = [r.abs() for r in roots]
    aar_list+=[(bound,aar)]
    # compute absolute value for each root (before any conversion)
    if aar!=[]:
        minn = min(aar)                                         # minimum modulus
        #mins_list+=[(bound,minn)]
        mins_list.append((bound,minn))
        log_minn=log(minn)
        log_mins_list.append((bound,log_minn))
    if 1==1:
        test=(pl.det()/factorial(bound))/(partition_number(bound))
        if test!=1:
            no.append(bound)
        print("n:",bound,"test:",test)
p = list_plot(mins_list, plotjoined=True, axes_labels=['', ''])
print("MINIMUM MODULI")
p.show()
p = list_plot(log_mins_list, plotjoined=False, pointsize=5, axes_labels=['', ''])
print("LOGS MINIMUM MODULI")
p.show()
print("no:",no)
# Out:
# n: 2 test: 1
# n: 3 test: 1
# n: 4 test: 1
# n: 5 test: 1
# n: 6 test: 1
# n: 7 test: 1
# n: 8 test: 1
# n: 9 test: 1
# MINIMUM MODULI
# Graphics object consisting of 1 graphics primitive
# LOGS MINIMUM MODULI
# Graphics object consisting of 1 graphics primitive
# no: []

# %%
def P_matrix(lst):
    lenlist=len(lst)
    columns=[lst]
    for k in range(1,lenlist):
        column=[0]*(k-1)
        column=column+[-k]
        column=flatten(column+[lst])
        column=column+[lst]
        column=column[:lenlist]
        columns+=[column]
    return (matrix(columns)).transpose()

import pickle
with open('/Users/barrybrent/data/run29sept25no1.txt', 'rb') as rfile:
    s_list = pickle.load(rfile)
j_list=s_list[1:]
from sage.all import *
from sage.combinat.partition import number_of_partitions as partition_number
precision_bits = 100
CIF = ComplexIntervalField(precision_bits)
x = polygen(QQ)  # Can remain in preamble if all polynomials are in one variable
matrix_list=[]
charpol_list=[]
roots_list=[]
aar_list=[]
centers_list=[]
max_diameter_list=[]
mins_list=[]
log_mins_list=[]
no=[]
for bound in range(2,200):
    lst=j_list[:bound]
    inpt=[j for j in lst]
    pl=P_matrix(inpt)
    matrix_list+=[(bound,pl)]
    cp=pl.charpoly()
    charpol_list+=[(bound,cp)]
    roots = cp.roots(ring=CIF, multiplicities=False)        # produces list of roots as Sage objects
    roots_list+=[(bound,roots)]
    centers=[r.center() for r in roots]
    centers_list+=[(bound,centers)]
    pairs = [(z.real(), z.imag()) for z in centers]

# Plot the points (no lines, small points, only axis ticks)
    #p = list_plot(pairs, plotjoined=False, pointsize=10, axes_labels=['', ''])
    #p.show()

    max_diameter=max([r.diameter() for r in roots])
    max_diameter_list+=[(bound,max_diameter)]
    aar = [r.abs() for r in roots]
    aar_list+=[(bound,aar)]
    # compute absolute value for each root (before any conversion)
    if aar!=[]:
        minn = min(aar)                                         # minimum modulus
        #mins_list+=[(bound,minn)]
        mins_list.append((bound,minn))
        log_minn=log(minn)
        log_mins_list.append((bound,log_minn))
    
    test=(pl.det()/factorial(bound))/(partition_number(bound))
    if test!=1:
        no.append(bound)
    print("n:",bound,"test:",test)
p = list_plot(mins_list, plotjoined=True, axes_labels=['', ''])
print("MINIMUM MODULI")
p.show()
p = list_plot(log_mins_list, plotjoined=False, pointsize=5, axes_labels=['', ''])
print("LOGS MINIMUM MODULI")
p.show()
print("no:",no)
with open('/Users/barrybrent/data/run29sept25no2.txt', 'wb') as wfile:
    pickle.dump(roots_list, wfile) #output snipped
with open('/Users/barrybrent/data/run29sept25no3.txt', 'wb') as wfile:
    pickle.dump(charpol_list, wfile) #output snipped
with open('/Users/barrybrent/data/run29sept25no4.txt', 'wb') as wfile:
    pickle.dump(max_diameter_list, wfile) #output snipped
with open('/Users/barrybrent/data/run29sept25no5.txt', 'wb') as wfile:
    pickle.dump(centers_list, wfile) #output snipped
# Out:
# n: 2 test: 1
# n: 3 test: 1
# n: 4 test: 1
# n: 5 test: 1
# n: 6 test: 1
# n: 7 test: 1
# n: 8 test: 1
# n: 9 test: 1
# n: 10 test: 1
# n: 11 test: 1
# n: 12 test: 1
# n: 13 test: 1
# n: 14 test: 1
# n: 15 test: 1
# n: 16 test: 1
# n: 17 test: 1
# n: 18 test: 1
# n: 19 test: 1
# n: 20 test: 1
# n: 21 test: 1
# n: 22 test: 1
# n: 23 test: 1
# n: 24 test: 1
# n: 174 test: 1
# n: 175 test: 1
# n: 176 test: 1
# n: 177 test: 1
# n: 178 test: 1
# n: 179 test: 1
# n: 180 test: 1
# n: 181 test: 1
# n: 182 test: 1
# n: 183 test: 1
# n: 184 test: 1
# n: 185 test: 1
# n: 186 test: 1
# n: 187 test: 1
# n: 188 test: 1
# n: 189 test: 1
# n: 190 test: 1
# n: 191 test: 1
# n: 192 test: 1
# n: 193 test: 1
# n: 194 test: 1
# n: 195 test: 1
# n: 196 test: 1
# n: 197 test: 1
# n: 198 test: 1
# n: 199 test: 1
# MINIMUM MODULI
# Graphics object consisting of 1 graphics primitive
# LOGS MINIMUM MODULI
# Graphics object consisting of 1 graphics primitive
# no: []

# %%
def P_matrix(lst):
    lenlist=len(lst)
    columns=[lst]
    for k in range(1,lenlist):
        column=[0]*(k-1)
        column=column+[-k]
        column=flatten(column+[lst])
        column=column+[lst]
        column=column[:lenlist]
        columns+=[column]
    return (matrix(columns)).transpose()

import pickle
with open('/Users/barrybrent/data/run29sept25no1.txt', 'rb') as rfile:
    s_list = pickle.load(rfile)
j_list=s_list[1:]
from sage.all import *
from sage.combinat.partition import number_of_partitions as partition_number
precision_bits = 100
CIF = ComplexIntervalField(precision_bits)
x = polygen(QQ)  # Can remain in preamble if all polynomials are in one variable
matrix_list=[]
charpol_list=[]
roots_list=[]
aar_list=[]
centers_list=[]
max_diameter_list=[]
mins_list=[]
exp_mins_list=[]
no=[]
for bound in range(2,100):
    lst=j_list[:bound]
    inpt=[j for j in lst]
    pl=P_matrix(inpt)
    matrix_list+=[(bound,pl)]
    cp=pl.charpoly()
    charpol_list+=[(bound,cp)]
    roots = cp.roots(ring=CIF, multiplicities=False)        # produces list of roots as Sage objects
    roots_list+=[(bound,roots)]
    centers=[r.center() for r in roots]
    centers_list+=[(bound,centers)]
    pairs = [(z.real(), z.imag()) for z in centers]

# Plot the points (no lines, small points, only axis ticks)
    #p = list_plot(pairs, plotjoined=False, pointsize=10, axes_labels=['', ''])
    #p.show()

    max_diameter=max([r.diameter() for r in roots])
    max_diameter_list+=[(bound,max_diameter)]
    aar = [r.abs() for r in roots]
    aar_list+=[(bound,aar)]
    # compute absolute value for each root (before any conversion)
    if aar!=[]:
        minn = min(aar)                                         # minimum modulus
        #mins_list+=[(bound,minn)]
        mins_list.append((bound,minn))
        exp_minn=exp(minn)
        exp_mins_list.append((bound,exp_minn))
    
    test=(pl.det()/factorial(bound))/(partition_number(bound))
    if test!=1:
        no.append(bound)
    print("n:",bound,"test:",test)
p = list_plot(mins_list, plotjoined=True, axes_labels=['', ''])
print("MINIMUM MODULI")
p.show()
p = list_plot(exp_mins_list, plotjoined=False, pointsize=5, axes_labels=['', ''])
print("EXPS MINIMUM MODULI")
p.show()
print("no:",no)
# Out:
# n: 2 test: 1
# n: 3 test: 1
# n: 4 test: 1
# n: 5 test: 1
# n: 6 test: 1
# n: 7 test: 1
# n: 8 test: 1
# n: 9 test: 1
# n: 10 test: 1
# n: 11 test: 1
# n: 12 test: 1
# n: 13 test: 1
# n: 14 test: 1
# n: 15 test: 1
# n: 16 test: 1
# n: 17 test: 1
# n: 18 test: 1
# n: 19 test: 1
# n: 20 test: 1
# n: 21 test: 1
# n: 22 test: 1
# n: 23 test: 1
# n: 24 test: 1
# n: 25 test: 1
# n: 26 test: 1
# n: 27 test: 1
# n: 28 test: 1
# n: 29 test: 1
# n: 30 test: 1
# n: 31 test: 1
# n: 32 test: 1
# n: 33 test: 1
# n: 34 test: 1
# n: 35 test: 1
# n: 36 test: 1
# n: 37 test: 1
# n: 38 test: 1
# n: 39 test: 1
# n: 40 test: 1
# n: 41 test: 1
# n: 42 test: 1
# n: 43 test: 1
# n: 44 test: 1
# n: 45 test: 1
# n: 46 test: 1
# n: 47 test: 1
# n: 48 test: 1
# n: 49 test: 1
# n: 50 test: 1
# n: 51 test: 1
# n: 52 test: 1
# n: 53 test: 1
# n: 54 test: 1
# n: 55 test: 1
# n: 56 test: 1
# n: 57 test: 1
# n: 58 test: 1
# n: 59 test: 1
# n: 60 test: 1
# n: 61 test: 1
# n: 62 test: 1
# n: 63 test: 1
# n: 64 test: 1
# n: 65 test: 1
# n: 66 test: 1
# n: 67 test: 1
# n: 68 test: 1
# n: 69 test: 1
# n: 70 test: 1
# n: 71 test: 1
# n: 72 test: 1
# n: 73 test: 1
# n: 74 test: 1
# n: 75 test: 1
# n: 76 test: 1
# n: 77 test: 1
# n: 78 test: 1
# n: 79 test: 1
# n: 80 test: 1
# n: 81 test: 1
# n: 82 test: 1
# n: 83 test: 1
# n: 84 test: 1
# n: 85 test: 1
# n: 86 test: 1
# n: 87 test: 1
# n: 88 test: 1
# n: 89 test: 1
# n: 90 test: 1
# n: 91 test: 1
# n: 92 test: 1
# n: 93 test: 1
# n: 94 test: 1
# n: 95 test: 1
# n: 96 test: 1
# n: 97 test: 1
# n: 98 test: 1
# n: 99 test: 1
# MINIMUM MODULI
# Graphics object consisting of 1 graphics primitive
# EXPS MINIMUM MODULI
# Graphics object consisting of 1 graphics primitive
# no: []

# %%
def P_matrix(lst):
    lenlist=len(lst)
    columns=[lst]
    for k in range(1,lenlist):
        column=[0]*(k-1)
        column=column+[-k]
        column=flatten(column+[lst])
        column=column+[lst]
        column=column[:lenlist]
        columns+=[column]
    return (matrix(columns)).transpose()

import pickle
with open('/Users/barrybrent/data/run29sept25no1.txt', 'rb') as rfile:
    s_list = pickle.load(rfile)
j_list=s_list[1:]
from sage.all import *
from sage.combinat.partition import number_of_partitions as partition_number
precision_bits = 100
CIF = ComplexIntervalField(precision_bits)
x = polygen(QQ)  # Can remain in preamble if all polynomials are in one variable
matrix_list=[]
charpol_list=[]
roots_list=[]
aar_list=[]
centers_list=[]
max_diameter_list=[]
max_list=[]
log_max_list=[]
no=[]
for bound in range(2,50):
    lst=j_list[:bound]
    inpt=[j for j in lst]
    pl=P_matrix(inpt)
    matrix_list+=[(bound,pl)]
    cp=pl.charpoly()
    charpol_list+=[(bound,cp)]
    roots = cp.roots(ring=CIF, multiplicities=False)        # produces list of roots as Sage objects
    roots_list+=[(bound,roots)]
    centers=[r.center() for r in roots]
    centers_list+=[(bound,centers)]
    pairs = [(z.real(), z.imag()) for z in centers]

# Plot the points (no lines, small points, only axis ticks)
    #p = list_plot(pairs, plotjoined=False, pointsize=10, axes_labels=['', ''])
    #p.show()

    max_diameter=max([r.diameter() for r in roots])
    max_diameter_list+=[(bound,max_diameter)]
    aar = [r.abs() for r in roots]
    aar_list+=[(bound,aar)]
    # compute absolute value for each root (before any conversion)
    if aar!=[]:
        maxx = max(aar)                                         # minimum modulus
        #mins_list+=[(bound,minn)]
        max_list.append((bound,maxx))
        log_max=log(maxx)
        log_max_list.append((bound,log_max))
    
    test=(pl.det()/factorial(bound))/(partition_number(bound))
    if test!=1:
        no.append(bound)
    print("n:",bound,"test:",test,"max:",CC(maxx))
p = list_plot(max_list, plotjoined=True, axes_labels=['', ''])
print("MAXIMUM MODULI")
p.show()
p = list_plot(log_max_list, plotjoined=False, pointsize=5, axes_labels=['', ''])
print("LOGS MAXIMUM MODULI")
p.show()
print("no:",no)
# Out:
# n: 2 test: 1 max: 2.00000000000000
# n: 3 test: 1 max: 3.13949359856729
# n: 4 test: 1 max: 4.20563917462803
# n: 5 test: 1 max: 5.31757980891367
# n: 6 test: 1 max: 6.45637530998944
# n: 7 test: 1 max: 7.58788919778013
# n: 8 test: 1 max: 8.71456777456977
# n: 9 test: 1 max: 9.84189381744174
# n: 10 test: 1 max: 10.9714143621457
# n: 11 test: 1 max: 12.1026492701716
# n: 12 test: 1 max: 13.2345388935831
# n: 13 test: 1 max: 14.3662330309873
# n: 14 test: 1 max: 15.4973150045292
# n: 15 test: 1 max: 16.6276939460994
# n: 16 test: 1 max: 17.7574290026845
# n: 17 test: 1 max: 18.8866052309989
# n: 18 test: 1 max: 20.0152780288241
# n: 19 test: 1 max: 21.1434639120044
# n: 20 test: 1 max: 22.2711518720996
# n: 21 test: 1 max: 23.3983185586163
# n: 22 test: 1 max: 24.5249398795749
# n: 23 test: 1 max: 25.6509974306218
# n: 24 test: 1 max: 26.7764807192429
# n: 25 test: 1 max: 27.9013867774418
# n: 26 test: 1 max: 29.0257185407097
# n: 27 test: 1 max: 30.1494829231132
# n: 28 test: 1 max: 31.2726891025901
# n: 29 test: 1 max: 32.3953472285856
# n: 30 test: 1 max: 33.5174675781288
# n: 31 test: 1 max: 34.6390600912310
# n: 32 test: 1 max: 35.7601341824601
# n: 33 test: 1 max: 36.8806987272802
# n: 34 test: 1 max: 38.0007621406083
# n: 35 test: 1 max: 39.1203324889655
# n: 36 test: 1 max: 40.2394175998538
# n: 37 test: 1 max: 41.3580251495848
# n: 38 test: 1 max: 42.4761627230590
# n: 39 test: 1 max: 43.5938378465368
# n: 40 test: 1 max: 44.7110579983217
# n: 41 test: 1 max: 45.8278306036350
# n: 42 test: 1 max: 46.9441630197786
# n: 43 test: 1 max: 48.0600625166937
# n: 44 test: 1 max: 49.1755362567422
# n: 45 test: 1 max: 50.2905912762676
# n: 46 test: 1 max: 51.4052344704045
# n: 47 test: 1 max: 52.5194725817586
# n: 48 test: 1 max: 53.6333121929841
# n: 49 test: 1 max: 54.7467597229032
# MAXIMUM MODULI
# Graphics object consisting of 1 graphics primitive
# LOGS MAXIMUM MODULI
# Graphics object consisting of 1 graphics primitive
# no: []
