# %%
def P_matrix(lst):
    lenlist=len(lst)
    columns=[lst]
    for k in range(1,lenlist):
        column=[0]*(k-1)
        column=column+[-k]
        column=flatten(column+[lst])
        column=column+[lst]
        column=column[:lenlist]
        print("length of column k:",len(column))
        print("column",k,":")
        print(column)
        columns+=[column]
    print("number of columns:",len(columns))
    return (matrix(columns)).transpose()

lst=[1/2,1/3,1/4]
print("lenlist:",len(lst))
pl=P_matrix(lst)
print("pl:")
print(pl)    
#print(matrix(pl))
# Out:
# lenlist: 3
# length of column k: 3
# column 1 :
# [-1, 1/2, 1/3]
# length of column k: 3
# column 2 :
# [0, -2, 1/2]
# number of columns: 3
# pl:
# [1/2  -1   0]
# [1/3 1/2  -2]
# [1/4 1/3 1/2]

# %%
def P_matrix(lst):
    lenlist=len(lst)
    columns=[lst]
    for k in range(1,lenlist):
        column=[0]*(k-1)
        column=column+[-k]
        column=flatten(column+[lst])
        column=column+[lst]
        column=column[:lenlist]
        print("length of column k:",len(column))
        print("column",k,":")
        print(column)
        columns+=[column]
    print("number of columns:",len(columns))
    return (matrix(columns)).transpose()

lst=[1/2,1/3,1/4,1/5,1/6]
print("lenlist:",len(lst))
pl=P_matrix(lst)
print("pl:")
print(pl)    
print("characteristic polynomial:")
print(pl.charpoly())
# Out:
# lenlist: 5
# length of column k: 5
# column 1 :
# [-1, 1/2, 1/3, 1/4, 1/5]
# length of column k: 5
# column 2 :
# [0, -2, 1/2, 1/3, 1/4]
# length of column k: 5
# column 3 :
# [0, 0, -3, 1/2, 1/3]
# length of column k: 5
# column 4 :
# [0, 0, 0, -4, 1/2]
# number of columns: 5
# pl:
# [1/2  -1   0   0   0]
# [1/3 1/2  -2   0   0]
# [1/4 1/3 1/2  -3   0]
# [1/5 1/4 1/3 1/2  -4]
# [1/6 1/5 1/4 1/3 1/2]
# characteristic polynomial:
# x^5 - 5/2*x^4 + 35/6*x^3 - 45/4*x^2 + 743/48*x - 1075/96

# %%
def P_matrix(lst):
    lenlist=len(lst)
    columns=[lst]
    for k in range(1,lenlist):
        column=[0]*(k-1)
        column=column+[-k]
        column=flatten(column+[lst])
        column=column+[lst]
        column=column[:lenlist]
        print("length of column k:",len(column))
        print("column",k,":")
        print(column)
        columns+=[column]
    print("number of columns:",len(columns))
    return (matrix(columns)).transpose()

lst=[1/2,1/3,1/4,1/5,1/6]
print("lenlist:",len(lst))
pl=P_matrix(lst)
print("pl:")
print(pl)    
print("characteristic polynomial")
cp=pl.charpoly()
print(cp)
roots=cp.real_roots()
from sage.rings.real_mpfr import RealField
RF = RealField(100)
aar= [abs(RF(r)) for r in roots]
print(aar)
minn=min(aar)
print("mimimum:",minn)
# Out:
# lenlist: 5
# length of column k: 5
# column 1 :
# [-1, 1/2, 1/3, 1/4, 1/5]
# length of column k: 5
# column 2 :
# [0, -2, 1/2, 1/3, 1/4]
# length of column k: 5
# column 3 :
# [0, 0, -3, 1/2, 1/3]
# length of column k: 5
# column 4 :
# [0, 0, 0, -4, 1/2]
# number of columns: 5
# pl:
# [1/2  -1   0   0   0]
# [1/3 1/2  -2   0   0]
# [1/4 1/3 1/2  -3   0]
# [1/5 1/4 1/3 1/2  -4]
# [1/6 1/5 1/4 1/3 1/2]
# characteristic polynomial
# x^5 - 5/2*x^4 + 35/6*x^3 - 45/4*x^2 + 743/48*x - 1075/96
# [1.3792391215174553131816992391]
# mimimum: 1.3792391215174553131816992391

# %%
from sage.all import sigma, nth_prime
import pickle

def nieburTau(n):
    def step1(n, k):
        return 35*k^4 - 52*k^3*n + 18*k^2*n^2
    def step2(n, k):
        return sigma(k) * sigma(n - k)
    def step3(n):
        ans = 0
        for k in range(1, n):
            ans += step1(n, k) * step2(n, k)
        return 24*ans
    return n^4 * sigma(n) - step3(n)

def primeTau(n):
    return nieburTau(nth_prime(n))   # ✅ works in Sage 10.6

prime_tau_lst = [(0,1)]
for k in range(1, 1001):
    prime_tau_lst.append([k, primeTau(k)])
    print(k)

with open('/Users/barrybrent/data/run27aug25no2.txt', 'wb') as wfile:
    pickle.dump(prime_tau_lst, wfile) #output snipped

import pickle
with open('/Users/barrybrent/data/run27aug25no2.txt', 'rb') as rfile:
    h_list = pickle.load(rfile)
def h(n):
    return h_list[n][1]
j0=1
j_lst=[(0,j0)]
for n in [1..1000]:
    sm=0
    for r in [1..n-1]:
        sm=sm+j_lst[r][1]*h(n-r)
    jn=n*h(n)-sm
    j_lst+=[(n,jn)]
    print(n)

with open('/Users/barrybrent/data/run1sept25no1.txt', 'wb') as wfile:
    pickle.dump(j_lst, wfile) #output snipped

# %%
import pickle
with open('/Users/barrybrent/data/run1sept25no1.txt', 'rb') as rfile:
    j_list = pickle.load(rfile)
print(j_list[:10])
# Out:
# [(0, 1), (1, -24), (2, -72), (3, 18810), (4, 518528), (5, 10323516), (6, 34401720), (7, -3989135538), (8, -155766935712), (9, -2992865260284)]

# %%
import pickle
with open('/Users/barrybrent/data/run1sept25no1.txt', 'rb') as rfile:
    j_list = pickle.load(rfile)
print(j_list[:5])
lst=j_list[:5]
def P_matrix(lst):
    lenlist=len(lst)
    columns=[lst]
    for k in range(1,lenlist):
        column=[0]*(k-1)
        column=column+[-k]
        column=flatten(column+[lst])
        column=column+[lst]
        column=column[:lenlist]
        print("length of column k:",len(column))
        print("column",k,":")
        print(column)
        columns+=[column]
    print("number of columns:",len(columns))
    return (matrix(columns)).transpose()
inpt=[pair[1] for pair in lst]
print(inpt)
pl=P_matrix(inpt)
print("pl:")
print(pl)    
print("characteristic polynomial")
cp=pl.charpoly()
print(cp)
roots=cp.real_roots()
from sage.rings.real_mpfr import RealField
RF = RealField(100)
aar= [abs(RF(r)) for r in roots]
print(aar)
minn=min(aar)
print("mimimum:",minn)
# Out:
# [(0, 1), (1, -24), (2, -72), (3, 18810), (4, 518528)]
# [1, -24, -72, 18810, 518528]
# length of column k: 5
# column 1 :
# [-1, 1, -24, -72, 18810]
# length of column k: 5
# column 2 :
# [0, -2, 1, -24, -72]
# length of column k: 5
# column 3 :
# [0, 0, -3, 1, -24]
# length of column k: 5
# column 4 :
# [0, 0, 0, -4, 1]
# number of columns: 5
# pl:
# [     1     -1      0      0      0]
# [   -24      1     -2      0      0]
# [   -72    -24      1     -3      0]
# [ 18810    -72    -24      1     -4]
# [518528  18810    -72    -24      1]
# characteristic polynomial
# x^5 - 5*x^4 - 230*x^3 + 2150*x^2 + 569345*x - 13050493
# [20.235851427676632141583468183]
# mimimum: 20.235851427676632141583468183

# %%
def P_matrix(lst):
    lenlist=len(lst)
    columns=[lst]
    for k in range(1,lenlist):
        column=[0]*(k-1)
        column=column+[-k]
        column=flatten(column+[lst])
        column=column+[lst]
        column=column[:lenlist]
        print("length of column k:",len(column))
        print("column",k,":")
        print(column)
        columns+=[column]
    print("number of columns:",len(columns))
    return (matrix(columns)).transpose()

import pickle
with open('/Users/barrybrent/data/run1sept25no1.txt', 'rb') as rfile:
    j_list = pickle.load(rfile)
print(j_list[1:5])
lst=j_list[1:5]
inpt=[pair[1] for pair in lst]
print(inpt)
pl=P_matrix(inpt)
print("pl:")
print(pl)    
print("characteristic polynomial")
cp=pl.charpoly()
print(cp)
roots=cp.real_roots()
from sage.rings.real_mpfr import RealField
RF = RealField(100)
aar= [abs(RF(r)) for r in roots]
print(aar)
minn=min(aar)
print("mimimum:",minn)
# Out:
# [(1, -24), (2, -72), (3, 18810), (4, 518528)]
# [-24, -72, 18810, 518528]
# length of column k: 4
# column 1 :
# [-1, -24, -72, 18810]
# length of column k: 4
# column 2 :
# [0, -2, -24, -72]
# length of column k: 4
# column 3 :
# [0, 0, -3, -24]
# number of columns: 4
# pl:
# [   -24     -1      0      0]
# [   -72    -24     -2      0]
# [ 18810    -72    -24     -3]
# [518528  18810    -72    -24]
# characteristic polynomial
# x^4 + 96*x^3 + 3024*x^2 - 115920*x - 401856
# [3.2225434994917177000672836584, 23.090726825017949153107110760]
# mimimum: 3.2225434994917177000672836584

# %%
def P_matrix(lst):
    lenlist=len(lst)
    columns=[lst]
    for k in range(1,lenlist):
        column=[0]*(k-1)
        column=column+[-k]
        column=flatten(column+[lst])
        column=column+[lst]
        column=column[:lenlist]
        print("length of column k:",len(column))
        print("column",k,":")
        print(column)
        columns+=[column]
    print("number of columns:",len(columns))
    return (matrix(columns)).transpose()

import pickle
with open('/Users/barrybrent/data/run1sept25no1.txt', 'rb') as rfile:
    j_list = pickle.load(rfile)
for bound in range(2,5):
    print(j_list[1:bound])
    lst=j_list[1:bound]
    inpt=[pair[1] for pair in lst]
    print(inpt)
    pl=P_matrix(inpt)
    print("pl:")
    print(pl)    
    print("characteristic polynomial")
    cp=pl.charpoly()
    print(cp)
    roots=cp.real_roots()
    from sage.rings.real_mpfr import RealField
    RF = RealField(100)
    aar= [abs(RF(r)) for r in roots]
    print(aar)
    minn=min(aar)
    print("mimimum:",minn)
    print("======================================================================================================")
# Out:
# [(1, -24)]
# [-24]
# number of columns: 1
# pl:
# [-24]
# characteristic polynomial
# x + 24
# [24.000000000000000000000000000]
# mimimum: 24.000000000000000000000000000
# ======================================================================================================
# [(1, -24), (2, -72)]
# [-24, -72]
# length of column k: 2
# column 1 :
# [-1, -24]
# number of columns: 2
# pl:
# [-24  -1]
# [-72 -24]
# characteristic polynomial
# x^2 + 48*x + 504
# [32.485281374238567764223262202, 15.514718625761430459419898398]
# mimimum: 15.514718625761430459419898398
# ======================================================================================================
# [(1, -24), (2, -72), (3, 18810)]
# [-24, -72, 18810]
# length of column k: 3
# column 1 :
# [-1, -24, -72]
# length of column k: 3
# column 2 :
# [0, -2, -24]
# number of columns: 3
# pl:
# [  -24    -1     0]
# [  -72   -24    -2]
# [18810   -72   -24]
# characteristic polynomial
# x^3 + 72*x^2 + 1512*x - 28980
# [11.653339577043411168233433273]
# mimimum: 11.653339577043411168233433273
# ======================================================================================================

# %%
def P_matrix(lst):
    lenlist=len(lst)
    columns=[lst]
    for k in range(1,lenlist):
        column=[0]*(k-1)
        column=column+[-k]
        column=flatten(column+[lst])
        column=column+[lst]
        column=column[:lenlist]
        print("length of column k:",len(column))
        print("column",k,":")
        print(column)
        columns+=[column]
    print("number of columns:",len(columns))
    return (matrix(columns)).transpose()

import pickle
with open('/Users/barrybrent/data/run1sept25no1.txt', 'rb') as rfile:
    j_list = pickle.load(rfile)
from sage.all import *
precision_bits = 100
CIF = ComplexIntervalField(precision_bits)
x = polygen(QQ)  # Can remain in preamble if all polynomials are in one variable
for bound in range(2,5):
    print(j_list[1:bound])
    lst=j_list[1:bound]
    inpt=[pair[1] for pair in lst]
    print(inpt)
    pl=P_matrix(inpt)
    print("pl:")
    print(pl)    
    print("characteristic polynomial")
    cp=pl.charpoly()
    print(cp)
    roots = cp.roots(ring=CIF, multiplicities=False)        # produces list of roots as Sage objects
    aar = [r.abs() for r in roots]
    # compute absolute value for each root (before any conversion)
    if aar!=[]:
        minn = min(aar)                                         # minimum modulus
        print(aar)
        print("minimum:", minn)
    print("======================================================================================================")
# Out:
# [(1, -24)]
# [-24]
# number of columns: 1
# pl:
# [-24]
# characteristic polynomial
# x + 24
# [24]
# minimum: 24
# ======================================================================================================
# [(1, -24), (2, -72)]
# [-24, -72]
# length of column k: 2
# column 1 :
# [-1, -24]
# number of columns: 2
# pl:
# [-24  -1]
# [-72 -24]
# characteristic polynomial
# x^2 + 48*x + 504
# [32.485281374238570292810132346?, 15.5147186257614297071898676547?]
# minimum: 15.5147186257614297071898676547?
# ======================================================================================================
# [(1, -24), (2, -72), (3, 18810)]
# [-24, -72, 18810]
# length of column k: 3
# column 1 :
# [-1, -24, -72]
# length of column k: 3
# column 2 :
# [0, -2, -24]
# number of columns: 3
# pl:
# [  -24    -1     0]
# [  -72   -24    -2]
# [18810   -72   -24]
# characteristic polynomial
# x^3 + 72*x^2 + 1512*x - 28980
# [11.6533395770434109240559409498?, 49.868234105941749197656827851?, 49.868234105941749197656827851?]
# minimum: 11.6533395770434109240559409498?
# ======================================================================================================

# %%
def P_matrix(lst):
    lenlist=len(lst)
    columns=[lst]
    for k in range(1,lenlist):
        column=[0]*(k-1)
        column=column+[-k]
        column=flatten(column+[lst])
        column=column+[lst]
        column=column[:lenlist]
        print("length of column k:",len(column))
        print("column",k,":")
        print(column)
        columns+=[column]
    print("number of columns:",len(columns))
    return (matrix(columns)).transpose()

import pickle
with open('/Users/barrybrent/data/run1sept25no1.txt', 'rb') as rfile:
    j_list = pickle.load(rfile)
from sage.all import *
precision_bits = 100
CIF = ComplexIntervalField(precision_bits)
x = polygen(QQ)  # Can remain in preamble if all polynomials are in one variable
matrix_list=[]
charpol_list=[]
roots_list=[]
aar_list=[]
mins_list=[]
for bound in range(2,5):
    print(j_list[1:bound])
    lst=j_list[1:bound]
    inpt=[pair[1] for pair in lst]
    pl=P_matrix(inpt)
    matrix_list+=[(bound,pl)]
    cp=pl.charpoly()
    charpol_list+=[(bound,cp)]
    roots = cp.roots(ring=CIF, multiplicities=False)        # produces list of roots as Sage objects
    roots_list+=[(bound,roots)]
    aar = [r.abs() for r in roots]
    aar_list+=[(bound,aar)]
    # compute absolute value for each root (before any conversion)
    if aar!=[]:
        minn = min(aar)                                         # minimum modulus
        mins_list+=[(bound,minn)]
    if bound<6:
        print("input:",inpt)
        print("matrix:")
        print(pl)    
        print("characteristic polynomial:")
        print(cp)
        print("roots:")
        print(roots)
        if aar!=[]:
            print("absolute values of the roots:")
            print(aar)
            print("minimum modulus:")
            print(minn)  
    print("======================================================================================================")
# Out:
# [(1, -24)]
# number of columns: 1
# input: [-24]
# matrix:
# [-24]
# characteristic polynomial:
# x + 24
# roots:
# [-24]
# absolute values of the roots:
# [24]
# minimum modulus:
# 24
# ======================================================================================================
# [(1, -24), (2, -72)]
# length of column k: 2
# column 1 :
# [-1, -24]
# number of columns: 2
# input: [-24, -72]
# matrix:
# [-24  -1]
# [-72 -24]
# characteristic polynomial:
# x^2 + 48*x + 504
# roots:
# [-32.4852813742385702928101323453?, -15.5147186257614297071898676548?]
# absolute values of the roots:
# [32.485281374238570292810132346?, 15.5147186257614297071898676547?]
# minimum modulus:
# 15.5147186257614297071898676547?
# ======================================================================================================
# [(1, -24), (2, -72), (3, 18810)]
# length of column k: 3
# column 1 :
# [-1, -24, -72]
# length of column k: 3
# column 2 :
# [0, -2, -24]
# number of columns: 3
# input: [-24, -72, 18810]
# matrix:
# [  -24    -1     0]
# [  -72   -24    -2]
# [18810   -72   -24]
# characteristic polynomial:
# x^3 + 72*x^2 + 1512*x - 28980
# roots:
# [11.6533395770434109240559409498?, -41.8266697885217054620279704749? - 27.1545662319797979280390910664?*I, -41.8266697885217054620279704749? + 27.1545662319797979280390910664?*I]
# absolute values of the roots:
# [11.6533395770434109240559409498?, 49.868234105941749197656827851?, 49.868234105941749197656827851?]
# minimum modulus:
# 11.6533395770434109240559409498?
# ======================================================================================================

# %%
def P_matrix(lst):
    lenlist=len(lst)
    columns=[lst]
    for k in range(1,lenlist):
        column=[0]*(k-1)
        column=column+[-k]
        column=flatten(column+[lst])
        column=column+[lst]
        column=column[:lenlist]
        columns+=[column]
    return (matrix(columns)).transpose()

import pickle
with open('/Users/barrybrent/data/run1sept25no1.txt', 'rb') as rfile:
    j_list = pickle.load(rfile)
from sage.all import *
precision_bits = 100
CIF = ComplexIntervalField(precision_bits)
x = polygen(QQ)  # Can remain in preamble if all polynomials are in one variable
matrix_list=[]
charpol_list=[]
roots_list=[]
aar_list=[]
centers_list=[]
max_diameter_list=[]
mins_list=[]
for bound in range(2,20):
    print("bound:",bound)
    lst=j_list[1:bound]
    inpt=[pair[1] for pair in lst]
    pl=P_matrix(inpt)
    matrix_list+=[(bound,pl)]
    cp=pl.charpoly()
    charpol_list+=[(bound,cp)]
    roots = cp.roots(ring=CIF, multiplicities=False)        # produces list of roots as Sage objects
    roots_list+=[(bound,roots)]
    centers=[r.center() for r in roots]
    pairs = [(z.real(), z.imag()) for z in centers]

# Plot the points (no lines, small points, only axis ticks)
    p = list_plot(pairs, plotjoined=False, pointsize=10, axes_labels=['', ''])
    p.show()
    centers_list+=[(bound,centers)]
    max_diameter=max([r.diameter() for r in roots])
    max_diameter_list+=[(bound,max_diameter)]
    aar = [r.abs() for r in roots]
    aar_list+=[(bound,aar)]
    # compute absolute value for each root (before any conversion)
    if aar!=[]:
        minn = min(aar)                                         # minimum modulus
        mins_list+=[(bound,minn)]
    if bound<6:
        print("input:",inpt)
        print("matrix:")
        print(pl)    
        print("characteristic polynomial:")
        print(cp)
        print("roots:")
        print(roots)
        print("centers:")
        print(centers)
        print("maximum radius:",.5*max_diameter)
          
        if aar!=[]:
            print("absolute values of the roots:")
            print(aar)
            print("minimum modulus:")
            print(minn)  
    print("======================================================================================================")
p = list_plot(mins_list, plotjoined=False, pointsize=10, axes_labels=['', ''])
print("MINIMUM MODULI")
p.show()
# Out:
# bound: 2
# Graphics object consisting of 1 graphics primitive
# input: [-24]
# matrix:
# [-24]
# characteristic polynomial:
# x + 24
# roots:
# [-24]
# centers:
# [-24.000000000000000000000000000]
# maximum radius: 0.000000000000000
# absolute values of the roots:
# [24]
# minimum modulus:
# 24
# ======================================================================================================
# bound: 3
# Graphics object consisting of 1 graphics primitive
# input: [-24, -72]
# matrix:
# [-24  -1]
# [-72 -24]
# characteristic polynomial:
# x^2 + 48*x + 504
# roots:
# [-32.4852813742385702928101323453?, -15.5147186257614297071898676548?]
# centers:
# [-32.485281374238570292810132345, -15.514718625761429707189867655]
# maximum radius: 2.44060652107058e-30
# absolute values of the roots:
# [32.485281374238570292810132346?, 15.5147186257614297071898676547?]
# minimum modulus:
# 15.5147186257614297071898676547?
# ======================================================================================================
# bound: 4
# Graphics object consisting of 1 graphics primitive
# input: [-24, -72, 18810]
# matrix:
# [  -24    -1     0]
# [  -72   -24    -2]
# [18810   -72   -24]
# characteristic polynomial:
# x^3 + 72*x^2 + 1512*x - 28980
# roots:
# [11.6533395770434109240559409498?, -41.8266697885217054620279704749? - 27.1545662319797979280390910664?*I, -41.8266697885217054620279704749? + 27.1545662319797979280390910664?*I]
# centers:
# [11.653339577043410924055940950, -41.826669788521705462027970475 - 27.154566231979797928039091066*I, -41.826669788521705462027970475 + 27.154566231979797928039091066*I]
# maximum radius: 2.32406114973613e-30
# absolute values of the roots:
# [11.6533395770434109240559409498?, 49.868234105941749197656827851?, 49.868234105941749197656827851?]
# minimum modulus:
# 11.6533395770434109240559409498?
# ======================================================================================================
# bound: 5
# Graphics object consisting of 1 graphics primitive
# input: [-24, -72, 18810, 518528]
# matrix:
# [   -24     -1      0      0]
# [   -72    -24     -2      0]
# [ 18810    -72    -24     -3]
# [518528  18810    -72    -24]
# characteristic polynomial:
# x^4 + 96*x^3 + 3024*x^2 - 115920*x - 401856
# roots:
# [-3.22254349949171790686783546240?, 23.0907268250179502315491269570?, -57.934091662763116162340645748? - 45.212190864260258093500538074?*I, -57.934091662763116162340645748? + 45.212190864260258093500538074?*I]
# centers:
# [-3.2225434994917179068678354624, 23.090726825017950231549126957, -57.934091662763116162340645747 - 45.212190864260258093500538073*I, -57.934091662763116162340645747 + 45.212190864260258093500538073*I]
# maximum radius: 2.23334003369672e-30
# absolute values of the roots:
# [3.22254349949171790686783546240?, 23.0907268250179502315491269570?, 73.488102299186754475017081569?, 73.488102299186754475017081569?]
# minimum modulus:
# 3.22254349949171790686783546240?
# ======================================================================================================
# bound: 6
# Graphics object consisting of 1 graphics primitive
# ======================================================================================================
# bound: 7
# Graphics object consisting of 1 graphics primitive
# ======================================================================================================
# bound: 8
# Graphics object consisting of 1 graphics primitive
# ======================================================================================================
# bound: 9
# Graphics object consisting of 1 graphics primitive
# ======================================================================================================
# bound: 10
# Graphics object consisting of 1 graphics primitive
# ======================================================================================================
# bound: 11
# Graphics object consisting of 1 graphics primitive
# ======================================================================================================
# bound: 12
# Graphics object consisting of 1 graphics primitive
# ======================================================================================================
# bound: 13
# Graphics object consisting of 1 graphics primitive
# ======================================================================================================
# bound: 14
# Graphics object consisting of 1 graphics primitive
# ======================================================================================================
# bound: 15
# Graphics object consisting of 1 graphics primitive
# ======================================================================================================
# bound: 16
# Graphics object consisting of 1 graphics primitive
# ======================================================================================================
# bound: 17
# Graphics object consisting of 1 graphics primitive
# ======================================================================================================
# bound: 18
# Graphics object consisting of 1 graphics primitive
# ======================================================================================================
# bound: 19
# Graphics object consisting of 1 graphics primitive
# ======================================================================================================
# MINIMUM MODULI
# Graphics object consisting of 1 graphics primitive

# %%
def P_matrix(lst):
    lenlist=len(lst)
    columns=[lst]
    for k in range(1,lenlist):
        column=[0]*(k-1)
        column=column+[-k]
        column=flatten(column+[lst])
        column=column+[lst]
        column=column[:lenlist]
        columns+=[column]
    return (matrix(columns)).transpose()

import pickle
with open('/Users/barrybrent/data/run1sept25no1.txt', 'rb') as rfile:
    j_list = pickle.load(rfile)
from sage.all import *
precision_bits = 100
CIF = ComplexIntervalField(precision_bits)
x = polygen(QQ)  # Can remain in preamble if all polynomials are in one variable
matrix_list=[]
charpol_list=[]
roots_list=[]
aar_list=[]
centers_list=[]
max_diameter_list=[]
mins_list=[]
for bound in range(2,300):
    print("bound:",bound)
    lst=j_list[1:bound]
    inpt=[pair[1] for pair in lst]
    pl=P_matrix(inpt)
    matrix_list+=[(bound,pl)]
    cp=pl.charpoly()
    charpol_list+=[(bound,cp)]
    roots = cp.roots(ring=CIF, multiplicities=False)        # produces list of roots as Sage objects
    roots_list+=[(bound,roots)]
    centers=[r.center() for r in roots]
    pairs = [(z.real(), z.imag()) for z in centers]

# Plot the points (no lines, small points, only axis ticks)
    if bound % 30 ==0:
       
        xs = [x for x, y in pairs]
        ys = [y for x, y in pairs]

# Compute bounds
        xmin, xmax = min(xs), max(xs)
        ymin, ymax = min(ys), max(ys)

# Expand by ten percent
        xrange = xmax - xmin
        yrange = ymax - ymin

        expand = 0.10
        xmin_exp = xmin - expand * xrange
        xmax_exp = xmax + expand * xrange
        ymin_exp = ymin - expand * yrange
        ymax_exp = ymax + expand * yrange

# List plot with window bounds
        p = list_plot(
        pairs,
        plotjoined=False,
        pointsize=3,
        color='red',
        axes_labels=['', ''],
        xmin=xmin_exp,
        xmax=xmax_exp,
        ymin=ymin_exp,
        ymax=ymax_exp
)
        p.show()
    centers_list+=[(bound,centers)]
    max_diameter=max([r.diameter() for r in roots])
    max_diameter_list+=[(bound,max_diameter)]
    aar = [r.abs() for r in roots]
    aar_list+=[(bound,aar)]
    # compute absolute value for each root (before any conversion)
    if aar!=[]:
        minn = min(aar)                                         # minimum modulus
        mins_list+=[(bound,minn)]
    if bound<6:
        print("input:",inpt)
        print("matrix:")
        print(pl)    
        print("characteristic polynomial:")
        print(cp)
        print("roots:")
        print(roots)
        print("centers:")
        print(centers)
        print("maximum radius:",.5*max_diameter)
          
        if aar!=[]:
            print("absolute values of the roots:")
            print(aar)
            print("minimum modulus:")
            print(minn)  
        print("======================================================================================================")
p = list_plot(mins_list, plotjoined=False, pointsize=10, axes_labels=['', ''])
print("MINIMUM MODULI")
p.show()
with open('/Users/barrybrent/data/run8sept25no1.txt', 'wb') as wfile:
    pickle.dump(matrix_list, wfile)
with open('/Users/barrybrent/data/run8sept25no2.txt', 'wb') as wfile:
    pickle.dump(charpol_list, wfile)
with open('/Users/barrybrent/data/run8sept25no3.txt', 'wb') as wfile:
    pickle.dump(aar_list, wfile)
with open('/Users/barrybrent/data/run8sept25no4.txt', 'wb') as wfile:
    pickle.dump(centers_list, wfile)
    pickle.dump(aar_list, wfile)
with open('/Users/barrybrent/data/run8sept25no5.txt', 'wb') as wfile:
    pickle.dump(max_diameter_list, wfile)
with open('/Users/barrybrent/data/run8sept25no6.txt', 'wb') as wfile:
    pickle.dump(mins_list, wfile)
# Out:
# bound: 2
# input: [-24]
# matrix:
# [-24]
# characteristic polynomial:
# x + 24
# roots:
# [-24]
# centers:
# [-24.000000000000000000000000000]
# maximum radius: 0.000000000000000
# absolute values of the roots:
# [24]
# minimum modulus:
# 24
# ======================================================================================================
# bound: 3
# input: [-24, -72]
# matrix:
# [-24  -1]
# [-72 -24]
# characteristic polynomial:
# x^2 + 48*x + 504
# roots:
# [-32.4852813742385702928101323453?, -15.5147186257614297071898676548?]
# centers:
# [-32.485281374238570292810132345, -15.514718625761429707189867655]
# maximum radius: 2.44060652107058e-30
# absolute values of the roots:
# [32.485281374238570292810132346?, 15.5147186257614297071898676547?]
# minimum modulus:
# 15.5147186257614297071898676547?
# ======================================================================================================
# bound: 4
# input: [-24, -72, 18810]
# matrix:
# [  -24    -1     0]
# [  -72   -24    -2]
# [18810   -72   -24]
# characteristic polynomial:
# x^3 + 72*x^2 + 1512*x - 28980
# roots:
# [11.6533395770434109240559409498?, -41.8266697885217054620279704749? - 27.1545662319797979280390910664?*I, -41.8266697885217054620279704749? + 27.1545662319797979280390910664?*I]
# centers:
# [11.653339577043410924055940950, -41.826669788521705462027970475 - 27.154566231979797928039091066*I, -41.826669788521705462027970475 + 27.154566231979797928039091066*I]
# maximum radius: 2.32406114973613e-30
# absolute values of the roots:
# [11.6533395770434109240559409498?, 49.868234105941749197656827851?, 49.868234105941749197656827851?]
# minimum modulus:
# 11.6533395770434109240559409498?
# ======================================================================================================
# bound: 5
# input: [-24, -72, 18810, 518528]
# matrix:
# [   -24     -1      0      0]
# [   -72    -24     -2      0]
# [ 18810    -72    -24     -3]
# [518528  18810    -72    -24]
# characteristic polynomial:
# x^4 + 96*x^3 + 3024*x^2 - 115920*x - 401856
# roots:
# [-3.22254349949171790686783546240?, 23.0907268250179502315491269570?, -57.934091662763116162340645748? - 45.212190864260258093500538074?*I, -57.934091662763116162340645748? + 45.212190864260258093500538074?*I]
# centers:
# [-3.2225434994917179068678354624, 23.090726825017950231549126957, -57.934091662763116162340645747 - 45.212190864260258093500538073*I, -57.934091662763116162340645747 + 45.212190864260258093500538073*I]
# maximum radius: 2.23334003369672e-30
# absolute values of the roots:
# [3.22254349949171790686783546240?, 23.0907268250179502315491269570?, 73.488102299186754475017081569?, 73.488102299186754475017081569?]
# minimum modulus:
# 3.22254349949171790686783546240?
# ======================================================================================================
# bound: 6
# bound: 7
# bound: 8
# bound: 9
# bound: 10
# bound: 11
# bound: 12
# bound: 13
# bound: 14
# bound: 15
# bound: 16
# bound: 17
# bound: 18
# bound: 19
# bound: 20
# bound: 21
# bound: 22
# bound: 23
# bound: 24
# bound: 25
# bound: 26
# bound: 27
# bound: 28
# bound: 29
# bound: 30
# Graphics object consisting of 1 graphics primitive
# bound: 31
# bound: 32
# bound: 33
# bound: 34
# bound: 35
# bound: 36
# bound: 37
# bound: 38
# bound: 39
# bound: 40
# bound: 41
# bound: 42
# bound: 43
# bound: 44
# bound: 45
# bound: 46
# bound: 47
# bound: 48
# bound: 49
# bound: 50
# bound: 51
# bound: 52
# bound: 53
# bound: 54
# bound: 55
# bound: 56
# bound: 57
# bound: 58
# bound: 59
# bound: 60
# Graphics object consisting of 1 graphics primitive
# bound: 61
# bound: 62
# bound: 63
# bound: 64
# bound: 65
# bound: 66
# bound: 67
# bound: 68
# bound: 69
# bound: 70
# bound: 71
# bound: 72
# bound: 73
# bound: 74
# bound: 75
# bound: 76
# bound: 77
# bound: 78
# bound: 79
# bound: 80
# bound: 81
# bound: 82
# bound: 83
# bound: 84
# bound: 85
# bound: 86
# bound: 87
# bound: 88
# bound: 89
# bound: 90
# Graphics object consisting of 1 graphics primitive
# bound: 91
# bound: 92
# bound: 93
# bound: 94
# bound: 95
# bound: 96
# bound: 97
# bound: 98
# bound: 99
# bound: 100
# bound: 101
# bound: 102
# bound: 103
# bound: 104
# bound: 105
# bound: 106
# bound: 107
# bound: 108
# bound: 109
# bound: 110
# bound: 111
# bound: 112
# bound: 113
# bound: 114
# bound: 115
# bound: 116
# bound: 117
# bound: 118
# bound: 119
# bound: 120
# Graphics object consisting of 1 graphics primitive
# bound: 121
# bound: 122
# bound: 123
# bound: 124
# bound: 125
# bound: 126
# bound: 127
# bound: 128
# bound: 129
# bound: 130
# bound: 131
# bound: 132
# bound: 133
# bound: 134
# bound: 135
# bound: 136
# bound: 137
# bound: 138
# bound: 139
# bound: 140
# bound: 141
# bound: 142
# bound: 143
# bound: 144
# bound: 145
# bound: 146
# bound: 147
# bound: 148
# bound: 149
# bound: 150
# Graphics object consisting of 1 graphics primitive
# bound: 151
# bound: 152
# bound: 153
# bound: 154
# bound: 155
# bound: 156
# bound: 157
# bound: 158
# bound: 159
# bound: 160
# bound: 161
# bound: 162
# bound: 163
# bound: 164
# bound: 165
# bound: 166
# bound: 167
# bound: 168
# bound: 169
# bound: 170
# bound: 171
# bound: 172
# bound: 173
# bound: 174
# bound: 175
# bound: 176
# bound: 177
# bound: 178
# bound: 179
# bound: 180
# Graphics object consisting of 1 graphics primitive
# bound: 181
# bound: 182
# bound: 183
# bound: 184
# bound: 185
# bound: 186
# bound: 187
# bound: 188
# bound: 189
# bound: 190
# bound: 191
# bound: 192
# bound: 193
# bound: 194
# bound: 195
# bound: 196
# bound: 197
# bound: 198
# bound: 199
# bound: 200
# bound: 201
# bound: 202
# bound: 203
# bound: 204
# bound: 205
# bound: 206
# bound: 207
# bound: 208
# bound: 209
# bound: 210
# Graphics object consisting of 1 graphics primitive
# bound: 211
# bound: 212
# bound: 213
# bound: 214
# bound: 215
# bound: 216
# bound: 217
# bound: 218
# bound: 219
# bound: 220
# bound: 221
# bound: 222
# bound: 223
# bound: 224
# bound: 225
# bound: 226
# bound: 227
# bound: 228
# bound: 229
# bound: 230
# bound: 231
# bound: 232
# bound: 233
# bound: 234
# bound: 235
# bound: 236
# bound: 237
# bound: 238
# bound: 239
# bound: 240
# Graphics object consisting of 1 graphics primitive
# bound: 241
# bound: 242
# bound: 243
# bound: 244
# bound: 245
# bound: 246
# bound: 247
# bound: 248
# bound: 249
# bound: 250
# bound: 251
# bound: 252
# bound: 253
# bound: 254
# bound: 255
# bound: 256
# bound: 257
# bound: 258
# bound: 259
# bound: 260
# bound: 261
# bound: 262
# bound: 263
# bound: 264
# bound: 265
# bound: 266
# bound: 267
# bound: 268
# bound: 269
# bound: 270
# Graphics object consisting of 1 graphics primitive
# bound: 271
# bound: 272
# bound: 273
# bound: 274
# bound: 275
# bound: 276
# bound: 277
# bound: 278
# bound: 279
# bound: 280
# bound: 281
# bound: 282
# bound: 283
# bound: 284
# bound: 285
# bound: 286
# bound: 287
# bound: 288
# bound: 289
# bound: 290
# bound: 291
# bound: 292
# bound: 293
# bound: 294
# bound: 295
# bound: 296
# bound: 297
# bound: 298
# bound: 299
# MINIMUM MODULI
# Graphics object consisting of 1 graphics primitive
