# %%
N=11
k=6
nf = Newforms(N, k, names='a')
for index in range(0,len(nf)):
    print("index:",index)
    f = nf[index]
    K = f.base_ring()
    print("K:",K)
# Out:
# index: 0
# K: Rational Field
# index: 1
# K: Number Field in a1 with defining polynomial x^3 - 90*x + 188

# %%
from sage.all import *
from sage.all import *
import pickle
import time


def trace_functional(K):
    """
    Returns a fast trace evaluator on K using its power basis.
    """
    d = K.degree()
    a = K.gen()

    # Precompute traces of basis elements
    basis = [a^i for i in range(d)]
    trace_vals = [b.trace() for b in basis]

    def tr(x):
        coeffs = x.polynomial().coefficients(sparse=False)
        # pad to full length
        coeffs += [0]*(d - len(coeffs))
        return sum(coeffs[i]*trace_vals[i] for i in range(d))

    return (tr,d)

def galois_orbit_sum(N, k, precision):
    S = CuspForms(N, k)
    dim_S=S.dimension()
    print("dimension of S:",dim_S)
    print()
    NF = S.newforms(names='a')
    dim_NF=S.new_subspace().dimension()
    print("dimension of NF:",dim_NF)
    print()
    results = []

    for f in NF:
        K = f.base_ring()
        qexp = f.q_expansion(precision)

        if K == QQ:
            results.append([QQ(qexp[n]) for n in range(precision)])
            
        if K !=QQ:
            tr = trace_functional(K)[0]
       
            coeffs = [QQ(tr(qexp[n])) for n in range(precision)]
            results.append(coeffs)

    return (results)

start=time.time()

N=11
k=6
        
precision=500 # need a long list to find 350 primes
gos=galois_orbit_sum(N, k, precision)
print("len(gos):",len(gos))
print()
for j in range(0,len(gos)):
    print("orbit",j)
    orbit=gos[j]
    indexed_list=[(n,orbit[n]) for n in range(1,500)]
    print(indexed_list[:20])
    print()
# Out:
# dimension of S: 4
#
# dimension of NF: 4
#
# len(gos): 2
#
# orbit 0
# [(1, 1), (2, -4), (3, -15), (4, -16), (5, -19), (6, 60), (7, 10), (8, 192), (9, -18), (10, 76), (11, -121), (12, 240), (13, -1148), (14, -40), (15, 285), (16, -256), (17, 686), (18, 72), (19, -384), (20, 304)]
#
# orbit 1
# [(1, 3), (2, 0), (3, 34), (4, 84), (5, 24), (6, -206), (7, 84), (8, -564), (9, -7), (10, -414), (11, 363), (12, 992), (13, 486), (14, -1020), (15, 1654), (16, 1992), (17, 1086), (18, -3706), (19, 1380), (20, -3480)]

# %%
from sage.all import *
import pickle

from sage.all import *
import pickle
import time


def trace_functional(K):
    """
    Returns a fast trace evaluator on K using its power basis.
    """
    d = K.degree()
    a = K.gen()

    # Precompute traces of basis elements
    basis = [a^i for i in range(d)]
    trace_vals = [b.trace() for b in basis]

    def tr(x):
        coeffs = x.polynomial().coefficients(sparse=False)
        # pad to full length
        coeffs += [0]*(d - len(coeffs))
        return sum(coeffs[i]*trace_vals[i] for i in range(d))

    return (tr,d)

def galois_orbit_sum(N, k, precision):
    S = CuspForms(N, k)
    dim_S=S.dimension()
    print("dimension of S:",dim_S)
    print()
    NF = S.newforms(names='a')
    dim_NF=S.new_subspace().dimension()
    print("dimension of NF:",dim_NF)
    print()
    results = []

    for f in NF:
        K = f.base_ring()
        qexp = f.q_expansion(precision)

        if K == QQ:
            results.append([QQ(qexp[n]) for n in range(precision)])
            
        if K !=QQ:
            tr = trace_functional(K)[0]
       
            coeffs = [QQ(tr(qexp[n])) for n in range(precision)]
            results.append(coeffs)

    return (results)
    
N=11
k=6
precision=400
gos=galois_orbit_sum(N, k, precision)
print("number of Galois orbits:",len(gos))
print()
print(gos[0][0:20])
print()
short=gos[0][1:20]
print(short)
print()
indexed_list=[(n,gos[0][n]) for n in range(0,len(gos[0]))]
print(indexed_list[:20])
print()
prime_list=[pair[1] for pair in indexed_list if is_prime(pair[0])]
print(prime_list[:20])
# Out:
# dimension of S: 4
#
# dimension of NF: 4
#
# number of Galois orbits: 2
#
# [0, 1, -4, -15, -16, -19, 60, 10, 192, -18, 76, -121, 240, -1148, -40, 285, -256, 686, 72, -384]
#
# [1, -4, -15, -16, -19, 60, 10, 192, -18, 76, -121, 240, -1148, -40, 285, -256, 686, 72, -384]
#
# [(0, 0), (1, 1), (2, -4), (3, -15), (4, -16), (5, -19), (6, 60), (7, 10), (8, 192), (9, -18), (10, 76), (11, -121), (12, 240), (13, -1148), (14, -40), (15, 285), (16, -256), (17, 686), (18, 72), (19, -384)]
#
# [-4, -15, -19, 10, -121, -1148, 686, -384, 3709, -5424, -6443, 12063, -1528, -4026, 7168, -29862, -6461, -16980, 29999, 31023]

# %%
from sage.all import *
import pickle
import time

start=time.time()
def trace_functional(K):
    d = K.degree()
    a = K.gen()
    basis = [a^i for i in range(d)]
    trace_vals = [b.trace() for b in basis]

    def tr(x):
        coeffs = x.polynomial().coefficients(sparse=False)
        coeffs += [0]*(d - len(coeffs))
        return sum(coeffs[i]*trace_vals[i] for i in range(d))

    return (tr,d)

def galois_orbit_sum(N, k, precision):
    S = CuspForms(N, k)
    dim_S=S.dimension()
    print("dimension of S:",dim_S)
    print()
    NF = S.newforms(names='a')
    dim_NF=S.new_subspace().dimension()
    print("dimension of NF:",dim_NF)
    print()
    results = []

    for f in NF:
        K = f.base_ring()
        qexp = f.q_expansion(precision)

        if K == QQ:
            results.append([QQ(qexp[n]) for n in range(precision)])
            
        if K !=QQ:
            tr = trace_functional(K)[0]
       
            coeffs = [QQ(tr(qexp[n])) for n in range(precision)]
            results.append(coeffs)

    return (results)
    
N=11
k=6
precision=500 
gos=galois_orbit_sum(N, k, precision)
orbit_0=gos[0]
print("length of orbit_0:",len(orbit_0))
print()
drop_constant=orbit_0[1:]
print("short drop_constant:")
print(drop_constant[:20])
print()

indexed_list=[(n,drop_constant[n]) for n in range(0,len(drop_constant))] 

h_list=[1]+[pair[1] for pair in indexed_list] # h_0 = 1 required by the lemmas

j_list=[(0,1)] #<<<<<<<<<< c = 1
for n in range(1,401):
    sm=0
    for r in range(1,n):
        sm=sm+j_list[r][1]*h_list[n-r] 
    j_n=n*h_list[n]-sm
    j_list.append((n,j_n))
    if n%20==0:
        print(("j_list",n))

N=11
k=6
precision=500 
gos=galois_orbit_sum(N, k, precision)
orbit_0=gos[0]
print("length of orbit_0:",len(orbit_1))
print()
print("orbit_0[:20]")
print(orbit_0[:20])
print()
print("orbit_0[1:20]")
print(orbit_0[1:20])
print()

h_list_2=[1]+orbit_0[1:]
print()
print("h_list_2[:20]")
print(h_list_2[:20])

j_list_2=[(0,1)] #<<<<<<<<<< c = 1
for n in range(1,401):
    sm=0
    for r in range(1,n):
        sm=sm+j_list_2[r][1]*h_list[n-r] 
    j_n=n*h_list[n]-sm
    j_list_2.append((n,j_n))
    if n%20==0:
        print(("j_list_2",n))

for n in range(0,20):
    print(j_list[n])
    print(j_list_2[n])
    print()
# Out:
# dimension of S: 4
#
# dimension of NF: 4
#
# length of orbit_0: 500
#
# short drop_constant:
# [1, -4, -15, -16, -19, 60, 10, 192, -18, 76, -121, 240, -1148, -40, 285, -256, 686, 72, -384, 304]
#
# ('j_list', 20)
# ('j_list', 40)
# ('j_list', 60)
# ('j_list', 80)
# ('j_list', 100)
# ('j_list', 120)
# ('j_list', 140)
# ('j_list', 160)
# ('j_list', 180)
# ('j_list', 200)
# ('j_list', 220)
# ('j_list', 240)
# ('j_list', 260)
# ('j_list', 280)
# ('j_list', 300)
# ('j_list', 320)
# ('j_list', 340)
# ('j_list', 360)
# ('j_list', 380)
# ('j_list', 400)
# dimension of S: 4
#
# dimension of NF: 4
#
# length of orbit_0: 500
#
# orbit_0[:20]
# [0, 1, -4, -15, -16, -19, 60, 10, 192, -18, 76, -121, 240, -1148, -40, 285, -256, 686, 72, -384]
#
# orbit_0[1:20]
# [1, -4, -15, -16, -19, 60, 10, 192, -18, 76, -121, 240, -1148, -40, 285, -256, 686, 72, -384]
#
#
# h_list_2[:20]
# [1, 1, -4, -15, -16, -19, 60, 10, 192, -18, 76, -121, 240, -1148, -40, 285, -256, 686, 72, -384]
# ('j_list_2', 20)
# ('j_list_2', 40)
# ('j_list_2', 60)
# ('j_list_2', 80)
# ('j_list_2', 100)
# ('j_list_2', 120)
# ('j_list_2', 140)
# ('j_list_2', 160)
# ('j_list_2', 180)
# ('j_list_2', 200)
# ('j_list_2', 220)
# ('j_list_2', 240)
# ('j_list_2', 260)
# ('j_list_2', 280)
# ('j_list_2', 300)
# ('j_list_2', 320)
# ('j_list_2', 340)
# ('j_list_2', 360)
# ('j_list_2', 380)
# ('j_list_2', 400)
# (0, 1)
# (0, 1)
#
# (1, 1)
# (1, 1)
#
# (2, -9)
# (2, -9)
#
# (3, -32)
# (3, -32)
#
# (4, -53)
# (4, -53)
#
# (5, -289)
# (5, -289)
#
# (6, -168)
# (6, -168)
#
# (7, -2456)
# (7, -2456)
#
# (8, -1941)
# (8, -1941)
#
# (9, -14378)
# (9, -14378)
#
# (10, -32399)
# (10, -32399)
#
# (11, -74271)
# (11, -74271)
#
# (12, -322460)
# (12, -322460)
#
# (13, -537783)
# (13, -537783)
#
# (14, -2486710)
# (14, -2486710)
#
# (15, -4937407)
# (15, -4937407)
#
# (16, -17281461)
# (16, -17281461)
#
# (17, -46806150)
# (17, -46806150)
#
# (18, -120769728)
# (18, -120769728)
#
# (19, -401505757)
# (19, -401505757)
